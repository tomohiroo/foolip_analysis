# %%
import csv

# %%
import matplotlib
print(matplotlib.matplotlib_fname())

import matplotlib as mpl
font = {"family":"AppleGothic"}
mpl.rc('font', **font)
# Out:
# /Users/uedatomohiro/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc

# %%
import matplotlib.pyplot as plt
% matplotlib inline

# %%
import numpy as np

# %%
csv_file = open("./グルメアプリ開発に活かすべくアンケートの協力をお願いしております。.csv", "r", encoding="ms932", errors="", newline="" )

# %%
f = csv.reader(csv_file, delimiter=",", doublequote=True, lineterminator="\r\n", quotechar='"', skipinitialspace=True)

# %%
import pandas as pd

# %%
df = pd.read_csv("./グルメアプリ開発に活かすべくアンケートの協力をお願いしております。.csv")

# %%
man_df = df[df.iloc[:,1]=='男']

# %%
man_df
# Out:
#                           タイムスタンプ 性別を教えてください。  \
# 0    2018/10/18 10:53:22 午後 GMT+9           男
# 1    2018/10/18 10:54:09 午後 GMT+9           男
# 2    2018/10/18 10:54:46 午後 GMT+9           男
# 4    2018/10/18 10:55:10 午後 GMT+9           男
# 6    2018/10/18 10:57:00 午後 GMT+9           男
# 7    2018/10/18 10:57:40 午後 GMT+9           男
# 8    2018/10/18 10:58:12 午後 GMT+9           男
# 9    2018/10/18 10:59:08 午後 GMT+9           男
# 10   2018/10/18 10:59:10 午後 GMT+9           男
# 11   2018/10/18 10:59:19 午後 GMT+9           男
# 12   2018/10/18 10:59:43 午後 GMT+9           男
# 13   2018/10/18 10:59:55 午後 GMT+9           男
# 14   2018/10/18 11:01:06 午後 GMT+9           男
# 15   2018/10/18 11:01:38 午後 GMT+9           男
# 16   2018/10/18 11:01:41 午後 GMT+9           男
# 17   2018/10/18 11:01:41 午後 GMT+9           男
# 18   2018/10/18 11:01:56 午後 GMT+9           男
# 19   2018/10/18 11:02:24 午後 GMT+9           男
# 20   2018/10/18 11:02:55 午後 GMT+9           男
# 21   2018/10/18 11:03:44 午後 GMT+9           男
# 22   2018/10/18 11:03:52 午後 GMT+9           男
# 23   2018/10/18 11:04:01 午後 GMT+9           男
# 24   2018/10/18 11:04:04 午後 GMT+9           男
# 25   2018/10/18 11:04:30 午後 GMT+9           男
# 26   2018/10/18 11:04:48 午後 GMT+9           男
# 27   2018/10/18 11:04:49 午後 GMT+9           男
# 29   2018/10/18 11:05:06 午後 GMT+9           男
# 32   2018/10/18 11:05:21 午後 GMT+9           男
# 35   2018/10/18 11:06:24 午後 GMT+9           男
# 36   2018/10/18 11:06:32 午後 GMT+9           男
# ..                            ...         ...
# 139   2018/10/19 9:05:20 午前 GMT+9           男
# 140   2018/10/19 9:05:38 午前 GMT+9           男
# 141   2018/10/19 9:13:32 午前 GMT+9           男
# 144   2018/10/19 9:21:29 午前 GMT+9           男
# 145   2018/10/19 9:22:04 午前 GMT+9           男
# 146   2018/10/19 9:34:56 午前 GMT+9           男
# 147   2018/10/19 9:40:03 午前 GMT+9           男
# 148  2018/10/19 10:11:10 午前 GMT+9           男
# 149  2018/10/19 10:30:42 午前 GMT+9           男
# 150  2018/10/19 10:53:15 午前 GMT+9           男
# 151  2018/10/19 11:02:00 午前 GMT+9           男
# 152  2018/10/19 11:52:25 午前 GMT+9           男
# 153  2018/10/19 12:11:31 午後 GMT+9           男
# 154  2018/10/19 12:27:12 午後 GMT+9           男
# 155  2018/10/19 12:34:55 午後 GMT+9           男
# 156  2018/10/19 12:59:35 午後 GMT+9           男
# 157   2018/10/19 1:09:35 午後 GMT+9           男
# 158   2018/10/19 1:32:26 午後 GMT+9           男
# 159   2018/10/19 1:33:31 午後 GMT+9           男
# 160   2018/10/19 1:48:04 午後 GMT+9           男
# 161   2018/10/19 1:54:44 午後 GMT+9           男
# 165   2018/10/19 2:47:12 午後 GMT+9           男
# 168   2018/10/19 5:04:05 午後 GMT+9           男
# 169   2018/10/19 5:07:15 午後 GMT+9           男
# 170   2018/10/19 5:21:07 午後 GMT+9           男
# 171   2018/10/19 8:54:57 午後 GMT+9           男
# 172  2018/10/19 10:08:32 午後 GMT+9           男
# 174  2018/10/20 11:50:20 午前 GMT+9           男
# 175   2018/10/20 2:48:10 午後 GMT+9           男
# 176   2018/10/20 2:51:49 午後 GMT+9           男
#
#     お気に入りの飲食店や行きたい飲食店の情報を何らかの方法でスマートフォン内に保存していますか？ 夜に外食する頻度を教えてください。  \
# 0                                              いいえ            2週間に1回
# 1                                              いいえ             週1-2回
# 2                                              いいえ             週1-2回
# 4                                              いいえ             週5回以上
# 6                                              いいえ             週1-2回
# 7                                              いいえ             週1-2回
# 8                                              いいえ            2週間に1回
# 9                                              いいえ         それよりもすくない
# 10                                              はい            2週間に1回
# 11                                             いいえ             週1-2回
# 12                                             いいえ             週1-2回
# 13                                             いいえ             週1-2回
# 14                                             いいえ             週3-4回
# 15                                              はい             週3-4回
# 16                                              はい             週5回以上
# 17                                             いいえ             週3-4回
# 18                                              はい             週1-2回
# 19                                             いいえ             週1-2回
# 20                                              はい             週1-2回
# 21                                             いいえ             週5回以上
# 22                                             いいえ             週5回以上
# 23                                              はい            2週間に1回
# 24                                             いいえ             週5回以上
# 25                                             いいえ             週3-4回
# 26                                             いいえ             週1-2回
# 27                                             いいえ             週1-2回
# 29                                              はい             週1-2回
# 32                                              はい             週1-2回
# 35                                              はい             週1-2回
# 36                                              はい             週1-2回
# ..                                             ...               ...
# 139                                            いいえ             週3-4回
# 140                                             はい            2週間に1回
# 141                                            いいえ             週1-2回
# 144                                            いいえ             週1-2回
# 145                                            いいえ             週1-2回
# 146                                             はい             週1-2回
# 147                                            いいえ        3週間-1ヶ月に一回
# 148                                            いいえ        3週間-1ヶ月に一回
# 149                                             はい             週1-2回
# 150                                            いいえ             週1-2回
# 151                                            いいえ             週5回以上
# 152                                            いいえ        3週間-1ヶ月に一回
# 153                                            いいえ             週3-4回
# 154                                             はい        3週間-1ヶ月に一回
# 155                                            いいえ             週3-4回
# 156                                             はい             週1-2回
# 157                                            いいえ             週1-2回
# 158                                             はい             週3-4回
# 159                                             はい             週3-4回
# 160                                            いいえ             週1-2回
# 161                                            いいえ             週5回以上
# 165                                            いいえ             週1-2回
# 168                                             はい             週5回以上
# 169                                             はい            2週間に1回
# 170                                             はい             週5回以上
# 171                                            いいえ             週1-2回
# 172                                            いいえ             週1-2回
# 174                                            いいえ             週1-2回
# 175                                            いいえ         それよりもすくない
# 176                                            いいえ             週3-4回
#
#     飲み会に行く頻度を教えてください。 バイトやインターンを教えてください(複数回答可能) 現在交際中の人はいますか？(任意回答)  \
# 0     ほとんど行かない / 行かない                    その他飲食店                 いない
# 1     ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 2     ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 4                 月1回                  塾講師・家庭教師                 いない
# 6                 月1回                    その他飲食店                 NaN
# 7              2週間に1回                  塾講師・家庭教師                 いない
# 8     ほとんど行かない / 行かない                    やっていない                 いない
# 9     ほとんど行かない / 行かない                    やっていない                 いない
# 10             2週間に1回                       NaN                 いない
# 11              週1~2日                       カフェ                 いない
# 12                月1回               エンジニア・デザイナー                 いない
# 13                月1回                  塾講師・家庭教師                  いる
# 14    ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 15                月1回                        採点                 いない
# 16                月1回                  塾講師・家庭教師                  いる
# 17             2週間に1回                  塾講師・家庭教師                 いない
# 18    ほとんど行かない / 行かない                    やっていない                  いる
# 19                月1回                  塾講師・家庭教師                 いない
# 20             2週間に1回                営業・マーケティング                 いない
# 21             2週間に1回                    やっていない                 いない
# 22                月1回       塾講師・家庭教師;営業・マーケティング                 いない
# 23                月1回      塾講師・家庭教師;エンジニア・デザイナー                 いない
# 24                月1回                  塾講師・家庭教師                 いない
# 25             2週間に1回                  塾講師・家庭教師                  いる
# 26             2週間に1回      塾講師・家庭教師;エンジニア・デザイナー                  いる
# 27                月1回                  塾講師・家庭教師                  いる
# 29                月1回                  塾講師・家庭教師                 NaN
# 32    ほとんど行かない / 行かない      塾講師・家庭教師;エンジニア・デザイナー                 いない
# 35                月1回      塾講師・家庭教師;エンジニア・デザイナー                  いる
# 36                月1回                    その他飲食店                 NaN
# ..                ...                       ...                 ...
# 139               月1回      塾講師・家庭教師;エンジニア・デザイナー                 いない
# 140   ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 141   ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 144   ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 145   ほとんど行かない / 行かない                    やっていない                 いない
# 146            2週間に1回                営業・マーケティング                  いる
# 147   ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 148             週1~2日                       人力車                  いる
# 149   ほとんど行かない / 行かない                 その他飲食店;案内                 いない
# 150            2週間に1回                    その他飲食店                 いない
# 151               月1回              塾講師・家庭教師;カフェ                  いる
# 152               月1回                  塾講師・家庭教師                 いない
# 153             週1~2日                    その他飲食店                  いる
# 154               月1回                        販売                 いない
# 155               月1回      塾講師・家庭教師;エンジニア・デザイナー                 いない
# 156               月1回                  塾講師・家庭教師                  いる
# 157               月1回               エンジニア・デザイナー                  いる
# 158             週1~2日      エンジニア・デザイナー;ライター・編集者                 いない
# 159            2週間に1回                  塾講師・家庭教師                 いない
# 160             週1~2日                    やっていない                 いない
# 161            2週間に1回            エンジニア・デザイナー;TA                  いる
# 165   ほとんど行かない / 行かない                    やっていない                 NaN
# 168            2週間に1回               エンジニア・デザイナー                  いる
# 169            2週間に1回                  塾講師・家庭教師                 いない
# 170             週1~2日               エンジニア・デザイナー                  いる
# 171               月1回                    やっていない                 いない
# 172            2週間に1回                    やっていない                 いない
# 174   ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 175   ほとんど行かない / 行かない                    やっていない                 いない
# 176            2週間に1回                  塾講師・家庭教師                  いる
#
#                       飲食店の情報はどこから仕入れることが多いですか？(複数選択可能)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 4                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                               食べログ;Twitter;口コミ;plat
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                     食べログ;Twitter;TV
# 16                                                 口コミ
# 17                                                 NaN
# 18                                           食べログ;ぐるなび
# 19                                                 NaN
# 20                               Instagram;Twitter;口コミ
# 21                                                 NaN
# 22                                                 NaN
# 23                                                食べログ
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 29                                    食べログ;Twitter;口コミ
# 32                          食べログ;Instagram;Twitter;口コミ
# 35                                        食べログ;ニュースアプリ
# 36                           食べログ;口コミ;雑誌;TV;Google Map
# ..                                                 ...
# 139                                                NaN
# 140                                                口コミ
# 141                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146            食べログ;Instagram;口コミ;SafariやChromeなどのブラウザ
# 147                                                NaN
# 148                                                NaN
# 149                                   食べログ;Twitter;口コミ
# 150                                                NaN
# 151                                                NaN
# 152                                                NaN
# 153                                                NaN
# 154                                               食べログ
# 155                                                NaN
# 156  食べログ;Instagram;Twitter;口コミ;SafariやChromeなどのブラウ...
# 157                                                NaN
# 158                             食べログ;Retty;TV;TERIYAKI
# 159                               食べログ;Retty;Instagram
# 160                                                NaN
# 161                                                NaN
# 165                                                NaN
# 168          Instagram;SafariやChromeなどのブラウザ;Hot Pepper
# 169  食べログ;Instagram;口コミ;SafariやChromeなどのブラウザ;Hot Pe...
# 170                             食べログ;Twitter;口コミ;雑誌;TV
# 171                                                NaN
# 172                                                NaN
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#                            飲食店の情報はどこに保存していますか？(複数選択可能)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 4                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                   脳
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15              スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」
# 16                                           スクリーンショット
# 17                                                 NaN
# 18                                           スクリーンショット
# 19                                                 NaN
# 20                                     スクリーンショット;お気に入り
# 21                                                 NaN
# 22                                                 NaN
# 23                                            evernote
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 29                                           スクリーンショット
# 32   メモアプリ(「iPhoneのメモ」、「Evernote」など);Twitterの「いいね」や...
# 35         メモアプリ(「iPhoneのメモ」、「Evernote」など);食べログの「行きたい」
# 36                                          Google Map
# ..                                                 ...
# 139                                                NaN
# 140                                          スクリーンショット
# 141                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                        食べログの「行きたい」
# 147                                                NaN
# 148                                                NaN
# 149                                          スクリーンショット
# 150                                                NaN
# 151                                                NaN
# 152                                                NaN
# 153                                                NaN
# 154                                          スクリーンショット
# 155                                                NaN
# 156  メモアプリ(「iPhoneのメモ」、「Evernote」など);Twitterの「いいね」や...
# 157                                                NaN
# 158                                 Googleマップ(行きたいリスト)
# 159      スクリーンショット;食べログの「行きたい」;Instagramの「コレクション」や「投稿」
# 160                                                NaN
# 161                                                NaN
# 165                                                NaN
# 168     スクリーンショット;SafariやChromeなどのブラウザの「ブックマーク」や「タブ」など
# 169                                          スクリーンショット
# 170                                         google map
# 171                                                NaN
# 172                                                NaN
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#     保存している飲食店に行くことはどれくらいありますか？ 気になった方に後日連絡するためにTwitterIDやLINEIDなどを教えてください。(任意)
# 0                          NaN                                             NaN
# 1                          NaN                                             NaN
# 2                          NaN                                             NaN
# 4                          NaN                                             NaN
# 6                          NaN                                             NaN
# 7                          NaN                                             NaN
# 8                          NaN                                             NaN
# 9                          NaN                                             NaN
# 10       実際にそこからお店に行くことはほとんどない                                         ディズニー行こ
# 11                         NaN                                             NaN
# 12                         NaN                                             NaN
# 13                         NaN                                             NaN
# 14                         NaN                                             NaN
# 15       実際にそこからお店に行くことはほとんどない                                             NaN
# 16       実際にそこからお店に行くことはほとんどない                            稲津です。必要なら中本から連絡ください。
# 17                         NaN                                             NaN
# 18                      月に1回程度                                             NaN
# 19                         NaN                                             NaN
# 20       実際にそこからお店に行くことはほとんどない                                             NaN
# 21                         NaN                                             NaN
# 22                         NaN                                             NaN
# 23       実際にそこからお店に行くことはほとんどない                                             NaN
# 24                         NaN                                             NaN
# 25                         NaN                                             NaN
# 26                         NaN                                             NaN
# 27                         NaN                                             NaN
# 29                      月に1回程度                                             NaN
# 32       実際にそこからお店に行くことはほとんどない                                             NaN
# 35                      月に1回程度                                             NaN
# 36                       週1~2日                                             NaN
# ..                         ...                                             ...
# 139                        NaN                                             NaN
# 140      実際にそこからお店に行くことはほとんどない                                             NaN
# 141                        NaN                                             NaN
# 144                        NaN                                             NaN
# 145                        NaN                                             NaN
# 146      実際にそこからお店に行くことはほとんどない                                             NaN
# 147                        NaN                                             NaN
# 148                        NaN                                             NaN
# 149                     月に1回程度                                             NaN
# 150                        NaN                                             NaN
# 151                        NaN                                             NaN
# 152                        NaN                                             NaN
# 153                        NaN                                             NaN
# 154                     月に1回程度                                             NaN
# 155                        NaN                                             NaN
# 156                     2週間に1回                                             NaN
# 157                        NaN                                             NaN
# 158                      週1~2日                                     @user_id_us
# 159                     2週間に1回                                        decers_9
# 160                        NaN                                             NaN
# 161                        NaN                                             NaN
# 165                        NaN                                             NaN
# 168      実際にそこからお店に行くことはほとんどない                                             NaN
# 169                     2週間に1回                                             NaN
# 170      実際にそこからお店に行くことはほとんどない                                      @sub_agent
# 171                        NaN                                             NaN
# 172                        NaN                                             NaN
# 174                        NaN                                             NaN
# 175                        NaN                                             NaN
# 176                        NaN                                             NaN
#
# [121 rows x 11 columns]

# %%
man_yes_num = len(man_df[man_df.iloc[:,2]=='はい'])
man_no_num = len(man_df[man_df.iloc[:,2]=='いいえ'])

# %%
man_yes_num/(man_no_num+man_yes_num)
# Out:
# 0.371900826446281

# %%
plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})
plt.axis('equal')
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
plt.pie([man_yes_num, man_no_num], labels=['yes','no'])
plt.show()

# %%
man_save = man_df[man_df.iloc[:,2]=='はい']

# %%
sources = [source.split(';') for source in man_save.iloc[:,7]]

# %%
from itertools import chain
sources = list(chain.from_iterable(sources))

sources_uniq = set(sources)

source_data = np.zeros(len(sources))
for (i, s) in enumerate(sources_uniq):
    for source in sources:
        if source == s:
            source_data[i] += 1

data = source_data
label = sources_uniq

import matplotlib.cm as cm

plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})

###各種パラメータ###
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
col=cm.Spectral(np.arange(len(data))/float(len(data))) #color指定はcolormapから好みのものを。

###pie###
plt.figure(figsize=size,dpi=100)
plt.pie(data, counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
plt.subplots_adjust(left=0,right=0.7)
plt.legend(label,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
plt.axis('equal') 
plt.savefig('figure.png',bbox_inches='tight',pad_inches=0.05)

# %%
oftens = [source.split(';') for source in man_save.iloc[:,9]]

# %%
often = list(chain.from_iterable(oftens))

often_uniq = set(often)

often_data = np.zeros(len(often))
for (i, s) in enumerate(often_uniq):
    for p in often:
        if p == s:
            often_data[i] += 1

data = often_data
label = often_uniq

import matplotlib.cm as cm

plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})

###各種パラメータ###
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
col=cm.Spectral(np.arange(len(data))/float(len(data))) #color指定はcolormapから好みのものを。

###pie###
plt.figure(figsize=size,dpi=100)
plt.pie(data, counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
plt.subplots_adjust(left=0,right=0.7)
plt.legend(label,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
plt.axis('equal') 
plt.savefig('figure.png',bbox_inches='tight',pad_inches=0.05)

# %%
man_save.iloc[:,8]
# Out:
# 10                                                     脳
# 15                スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」
# 16                                             スクリーンショット
# 18                                             スクリーンショット
# 20                                       スクリーンショット;お気に入り
# 23                                              evernote
# 29                                             スクリーンショット
# 32     メモアプリ(「iPhoneのメモ」、「Evernote」など);Twitterの「いいね」や...
# 35           メモアプリ(「iPhoneのメモ」、「Evernote」など);食べログの「行きたい」
# 36                                            Google Map
# 45                                             スクリーンショット
# 47                                      Safariでページを開いておく
# 49                       メモアプリ(「iPhoneのメモ」、「Evernote」など)
# 62                       メモアプリ(「iPhoneのメモ」、「Evernote」など)
# 65     スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Twit...
# 66      メモアプリ(「iPhoneのメモ」、「Evernote」など);safariのリーディングリスト
# 67                                 スクリーンショット;食べログの「行きたい」
# 69                                             スクリーンショット
# 70     スクリーンショット;食べログの「行きたい」;Twitterの「いいね」や「ツイート」や「モー...
# 72     スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Twit...
# 74                                           retripの保存機能
# 77                                           食べログの「行きたい」
# 85                                           食べログの「行きたい」
# 90                                 スクリーンショット;食べログの「行きたい」
# 92                                           食べログの「行きたい」
# 95                                           食べログの「行きたい」
# 102                                          食べログの「行きたい」
# 106                                スクリーンショット;食べログの「行きたい」
# 107                                            スクリーンショット
# 108                                           GoogleMaps
# 116                      メモアプリ(「iPhoneのメモ」、「Evernote」など)
# 118                               食べログの「行きたい」;google map
# 123                                          食べログの「行きたい」
# 126                                            スクリーンショット
# 131                                            スクリーンショット
# 140                                            スクリーンショット
# 146                                          食べログの「行きたい」
# 149                                            スクリーンショット
# 154                                            スクリーンショット
# 156    メモアプリ(「iPhoneのメモ」、「Evernote」など);Twitterの「いいね」や...
# 158                                   Googleマップ(行きたいリスト)
# 159        スクリーンショット;食べログの「行きたい」;Instagramの「コレクション」や「投稿」
# 168       スクリーンショット;SafariやChromeなどのブラウザの「ブックマーク」や「タブ」など
# 169                                            スクリーンショット
# 170                                           google map
# Name: 飲食店の情報はどこに保存していますか？(複数選択可能), dtype: object

# %%
pool = [source.split(';') for source in man_save.iloc[:,8]]

# %%
pool
# Out:
# [['脳'],
#  ['スクリーンショット', 'Twitterの「いいね」や「ツイート」や「モーメント」'],
#  ['スクリーンショット'],
#  ['スクリーンショット'],
#  ['スクリーンショット', 'お気に入り'],
#  ['evernote'],
#  ['スクリーンショット'],
#  ['メモアプリ(「iPhoneのメモ」、「Evernote」など)', 'Twitterの「いいね」や「ツイート」や「モーメント」'],
#  ['メモアプリ(「iPhoneのメモ」、「Evernote」など)', '食べログの「行きたい」'],
#  ['Google Map'],
#  ['スクリーンショット'],
#  ['Safariでページを開いておく'],
#  ['メモアプリ(「iPhoneのメモ」、「Evernote」など)'],
#  ['メモアプリ(「iPhoneのメモ」、「Evernote」など)'],
#  ['スクリーンショット',
#   'メモアプリ(「iPhoneのメモ」、「Evernote」など)',
#   'Twitterの「いいね」や「ツイート」や「モーメント」'],
#  ['メモアプリ(「iPhoneのメモ」、「Evernote」など)', 'safariのリーディングリスト'],
#  ['スクリーンショット', '食べログの「行きたい」'],
#  ['スクリーンショット'],
#  ['スクリーンショット', '食べログの「行きたい」', 'Twitterの「いいね」や「ツイート」や「モーメント」'],
#  ['スクリーンショット',
#   'メモアプリ(「iPhoneのメモ」、「Evernote」など)',
#   'Twitterの「いいね」や「ツイート」や「モーメント」'],
#  ['retripの保存機能'],
#  ['食べログの「行きたい」'],
#  ['食べログの「行きたい」'],
#  ['スクリーンショット', '食べログの「行きたい」'],
#  ['食べログの「行きたい」'],
#  ['食べログの「行きたい」'],
#  ['食べログの「行きたい」'],
#  ['スクリーンショット', '食べログの「行きたい」'],
#  ['スクリーンショット'],
#  ['GoogleMaps'],
#  ['メモアプリ(「iPhoneのメモ」、「Evernote」など)'],
#  ['食べログの「行きたい」', 'google map'],
#  ['食べログの「行きたい」'],
#  ['スクリーンショット'],
#  ['スクリーンショット'],
#  ['スクリーンショット'],
#  ['食べログの「行きたい」'],
#  ['スクリーンショット'],
#  ['スクリーンショット'],
#  ['メモアプリ(「iPhoneのメモ」、「Evernote」など)',
#   'Twitterの「いいね」や「ツイート」や「モーメント」',
#   'SafariやChromeなどのブラウザの「ブックマーク」や「タブ」など'],
#  ['Googleマップ(行きたいリスト)'],
#  ['スクリーンショット', '食べログの「行きたい」', 'Instagramの「コレクション」や「投稿」'],
#  ['スクリーンショット', 'SafariやChromeなどのブラウザの「ブックマーク」や「タブ」など'],
#  ['スクリーンショット'],
#  ['google map']]

# %%
pool = list(chain.from_iterable(pool))

pool_uniq = set(pool)

pool_data = np.zeros(len(pool))
for (i, s) in enumerate(pool_uniq):
    for p in pool:
        if p == s:
            pool_data[i] += 1

data = pool_data
label = pool_uniq

import matplotlib.cm as cm

plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})

###各種パラメータ###
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
col=cm.Spectral(np.arange(len(data))/float(len(data))) #color指定はcolormapから好みのものを。

###pie###
plt.figure(figsize=size,dpi=100)
plt.pie(data, counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
plt.subplots_adjust(left=0,right=0.7)
plt.legend(label,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
plt.axis('equal') 
plt.savefig('figure.png',bbox_inches='tight',pad_inches=0.05)
