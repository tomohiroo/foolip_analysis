# %% [markdown]
# # import

# %%
import csv

# %%
import matplotlib
import matplotlib as mpl
font = {"family":"AppleGothic"}
mpl.rc('font', **font)

# %%
import matplotlib.pyplot as plt
% matplotlib inline

# %%
import numpy as np

# %%
csv_file = open("./グルメアプリ開発に活かすべくアンケートの協力をお願いしております。.csv", "r", encoding="ms932", errors="", newline="" )

# %%
f = csv.reader(csv_file, delimiter=",", doublequote=True, lineterminator="\r\n", quotechar='"', skipinitialspace=True)

# %%
import pandas as pd

# %%
df = pd.read_csv("./グルメアプリ開発に活かすべくアンケートの協力をお願いしております。.csv")

# %%
df.shape
# Out:
# (180, 11)

# %%
df.head()
# Out:
#                         タイムスタンプ 性別を教えてください。  \
# 0  2018/10/18 10:53:22 午後 GMT+9           男
# 1  2018/10/18 10:54:09 午後 GMT+9           男
# 2  2018/10/18 10:54:46 午後 GMT+9           男
# 3  2018/10/18 10:54:56 午後 GMT+9           女
# 4  2018/10/18 10:55:10 午後 GMT+9           男
#
#   お気に入りの飲食店や行きたい飲食店の情報を何らかの方法でスマートフォン内に保存していますか？ 夜に外食する頻度を教えてください。  \
# 0                                            いいえ            2週間に1回
# 1                                             はい             週1-2回
# 2                                            いいえ             週1-2回
# 3                                             はい         それよりもすくない
# 4                                            いいえ             週5回以上
#
#   飲み会に行く頻度を教えてください。 バイトやインターンを教えてください(複数回答可能) 現在交際中の人はいますか？(任意回答)  \
# 0   ほとんど行かない / 行かない                    その他飲食店                 いない
# 1   ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 2   ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 3   ほとんど行かない / 行かない                  塾講師・家庭教師                  いる
# 4               月1回                  塾講師・家庭教師                 いない
#
#   飲食店の情報はどこから仕入れることが多いですか？(複数選択可能)  \
# 0                              NaN
# 1                  食べログ;Hot Pepper
# 2                              NaN
# 3                     食べログ;Twitter
# 4                              NaN
#
#                          飲食店の情報はどこに保存していますか？(複数選択可能)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Twit...
# 4                                                NaN
#
#   保存している飲食店に行くことはどれくらいありますか？ 気になった方に後日連絡するためにTwitterIDやLINEIDなどを教えてください。(任意)
# 0                        NaN                                             NaN
# 1                    特に保存しない                                             NaN
# 2                        NaN                                             NaN
# 3      実際にそこからお店に行くことはほとんどない                  @kajiguchi97 いつでもどうぞ。頑張ってください！
# 4                        NaN                                             NaN

# %%
def pie_chart(data, label):
    plt.style.use('ggplot')
    plt.rcParams.update({'font.size':15})

    ###各種パラメータ###
    size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
    col=cm.Spectral(np.arange(len(data))/float(len(data))) #color指定はcolormapから好みのものを。

    ###pie###
    plt.figure(figsize=size,dpi=100)
    plt.pie(data, counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
    plt.subplots_adjust(left=0,right=0.7)
    plt.legend(label,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
    plt.axis('equal') 
    plt.savefig('figure.png',bbox_inches='tight',pad_inches=0.05)

# %% [markdown]
# # 男

# %% [markdown]
# ## 保存する割合

# %%
man_df = df[df.iloc[:,1]=='男']

# %%
man_yes_num = len(man_df[man_df.iloc[:,2]=='はい'])
man_no_num = len(man_df[man_df.iloc[:,2]=='いいえ'])
man_yes_num/(man_no_num+man_yes_num)
plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})
plt.axis('equal')
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
plt.pie([man_yes_num, man_no_num], labels=['yes','no'])
plt.show()

# %%
man_yes_num / (man_yes_num + man_no_num)
# Out:
# 0.3770491803278688

# %% [markdown]
# 保存してる人が37%

# %% [markdown]
# ## どこから保存するか

# %%
man_save = man_df[man_df.iloc[:,2]=='はい']
sources = [source.split(';') for source in man_save.iloc[:,7]]
from itertools import chain
sources = list(chain.from_iterable(sources))

sources_uniq = set(sources)

source_data = np.zeros(len(sources))
for (i, s) in enumerate(sources_uniq):
    for source in sources:
        if source == s:
            source_data[i] += 1

data = source_data
label = sources_uniq

import matplotlib.cm as cm

plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})

###各種パラメータ###
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
col=cm.Spectral(np.arange(len(data))/float(len(data))) #color指定はcolormapから好みのものを。

###pie###
plt.figure(figsize=size,dpi=100)
plt.pie(data, counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
plt.subplots_adjust(left=0,right=0.7)
plt.legend(label,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
plt.axis('equal') 
plt.savefig('figure.png',bbox_inches='tight',pad_inches=0.05)

# %% [markdown]
# 食べログが27%
# ニュースアプリが14%
# instaが11.7%
# twitterが11.7%
# これで6割
#
# ニュースアプリ何なのか気になる（聞いてみる？）
#
# 口コミは14％でインスタより多い
#
# HotPepper,　ぐるなびのシェアは実装してもいいかも

# %% [markdown]
# ## 保存した店に行く頻度

# %%
oftens = [source.split(';') for source in man_save.iloc[:,9]]
often = list(chain.from_iterable(oftens))

often_uniq = set(often)

often_data = np.zeros(len(often))
for (i, s) in enumerate(often_uniq):
    for p in often:
        if p == s:
            often_data[i] += 1

data = often_data
label = often_uniq

import matplotlib.cm as cm

plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})

###各種パラメータ###
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
col=cm.Spectral(np.arange(len(data))/float(len(data))) #color指定はcolormapから好みのものを。

###pie###
plt.figure(figsize=size,dpi=100)
plt.pie(data, counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
plt.subplots_adjust(left=0,right=0.7)
plt.legend(label,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
plt.axis('equal') 
plt.savefig('figure.png',bbox_inches='tight',pad_inches=0.05)

# %% [markdown]
# 実際には行かない人が4割

# %% [markdown]
# ## どこに保存するか

# %%
pool = [source.split(';') for source in man_save.copy().dropna(subset=['飲食店の情報はどこに保存していますか？(複数選択可能)']).iloc[:,8]]
pool = list(chain.from_iterable(pool))

pool_uniq = set(pool)

pool_data = np.zeros(len(pool))
for (i, s) in enumerate(pool_uniq):
    for p in pool:
        if p == s:
            pool_data[i] += 1

data = pool_data
label = pool_uniq

import matplotlib.cm as cm

plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})

###各種パラメータ###
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
col=cm.Spectral(np.arange(len(data))/float(len(data))) #color指定はcolormapから好みのものを。

###pie###
plt.figure(figsize=size,dpi=100)
plt.pie(data, counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
plt.subplots_adjust(left=0,right=0.7)
plt.legend(label,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
plt.axis('equal') 
# plt.savefig('figure.png',bbox_inches='tight',pad_inches=0.05)

# %% [markdown]
# スクショが3割
#
# 食べログが2割
#
# これで5割
#
# 男はメモアプリも多い
#
# 食べログ勢の熱量多少ある層が2割
#
# instaのコレクションはほとんどいない
#
# メモが13%でtwitterも1割いる

# %% [markdown]
# # 女

# %% [markdown]
# ## 保存する割合

# %%
woman_df = df[df.iloc[:,1]=='女']
woman_yes_num = len(woman_df[woman_df.iloc[:,2]=='はい'])
woman_no_num = len(woman_df[woman_df.iloc[:,2]=='いいえ'])

# %%
woman_yes_num
# Out:
# 40

# %%
woman_no_num
# Out:
# 18

# %%
plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})
plt.axis('equal')
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
plt.pie([woman_yes_num, woman_no_num], labels=['yes','no'])
plt.show()

# %%
32 / 56
# Out:
# 0.5714285714285714

# %% [markdown]
# 保存する人が38人、しない人が18人
#
# する率が57%

# %% [markdown]
# ## どこから保存するか

# %%
woman_save = woman_df[woman_df.iloc[:,2]=='はい']
sources = [source.split(';') for source in woman_save.iloc[:,7]]

# %%
from itertools import chain
sources = list(chain.from_iterable(sources))

sources_uniq = set(sources)

source_data = np.zeros(len(sources))
for (i, s) in enumerate(sources_uniq):
    for source in sources:
        if source == s:
            source_data[i] += 1

data = source_data
label = sources_uniq

import matplotlib.cm as cm

plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})

###各種パラメータ###
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
col=cm.Spectral(np.arange(len(data))/float(len(data))) #color指定はcolormapから好みのものを。

###pie###
plt.figure(figsize=size,dpi=100)
plt.pie(data, counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
plt.subplots_adjust(left=0,right=0.7)
plt.legend(label,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
plt.axis('equal') 
plt.savefig('figure.png',bbox_inches='tight',pad_inches=0.05)

# %% [markdown]
# 男と全然違う
#
# 食べログが21％
#
# インスタが18％
#
# twitterが14％
#
# 口コミはやっぱりあんまりないみたい(insta⊃口コミって感じなのかな)
#
# ぐるなびとhotpepperは意外と1割強ずついる

# %% [markdown]
# ## 保存した店にどれくらい行くか

# %%
oftens = [source.split(';') for source in woman_save.iloc[:,9]]
often = list(chain.from_iterable(oftens))

often_uniq = set(often)

often_data = np.zeros(len(often))
for (i, s) in enumerate(often_uniq):
    for p in often:
        if p == s:
            often_data[i] += 1

data = often_data
label = often_uniq

import matplotlib.cm as cm

plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})

###各種パラメータ###
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
col=cm.Spectral(np.arange(len(data))/float(len(data))) #color指定はcolormapから好みのものを。

###pie###
plt.figure(figsize=size,dpi=100)
plt.pie(data, counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
plt.subplots_adjust(left=0,right=0.7)
plt.legend(label,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
plt.axis('equal') 
plt.savefig('figure.png',bbox_inches='tight',pad_inches=0.05)

# %% [markdown]
# 月1行く人が多いけどここは男とあんまり変わらないと行ってもいいのかな

# %% [markdown]
# ## どこに保存するか

# %%
pool = [source.split(';') for source in woman_save.iloc[:,8]]

# %%
pool = list(chain.from_iterable(pool))

pool_uniq = set(pool)

pool_data = np.zeros(len(pool))
for (i, s) in enumerate(pool_uniq):
    for p in pool:
        if p == s:
            pool_data[i] += 1

data = pool_data
label = pool_uniq

import matplotlib.cm as cm

plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})

###各種パラメータ###
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
col=cm.Spectral(np.arange(len(data))/float(len(data))) #color指定はcolormapから好みのものを。

###pie###
plt.figure(figsize=size,dpi=100)
plt.pie(data, counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
plt.subplots_adjust(left=0,right=0.7)
plt.legend(label,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
plt.axis('equal') 
plt.savefig('figure.png',bbox_inches='tight',pad_inches=0.05)

# %% [markdown]
# スクショがめちゃおおい。
#
# 男にはほぼなかったインスタのコレクションも意外と多い
#
# 食べログ使ってる人はほぼほぼいない←！！！！！
#
# やっぱりあんまりちゃんと管理してる人いない
#
# が、これが管理したいと思ってないのか、やりたいけどできてないのかはわからん

# %% [markdown]
# # 保存してる女としてない女の違い

# %%
len(woman_df)
# Out:
# 58

# %%
woman_df.head()
# Out:
#                          タイムスタンプ 性別を教えてください。  \
# 3   2018/10/18 10:54:56 午後 GMT+9           女
# 5   2018/10/18 10:55:12 午後 GMT+9           女
# 28  2018/10/18 11:05:04 午後 GMT+9           女
# 30  2018/10/18 11:05:15 午後 GMT+9           女
# 31  2018/10/18 11:05:17 午後 GMT+9           女
#
#    お気に入りの飲食店や行きたい飲食店の情報を何らかの方法でスマートフォン内に保存していますか？ 夜に外食する頻度を教えてください。  \
# 3                                              はい         それよりもすくない
# 5                                              はい             週1-2回
# 28                                             はい             週1-2回
# 30                                             はい            2週間に1回
# 31                                             はい             週1-2回
#
#    飲み会に行く頻度を教えてください。 バイトやインターンを教えてください(複数回答可能) 現在交際中の人はいますか？(任意回答)  \
# 3    ほとんど行かない / 行かない                  塾講師・家庭教師                  いる
# 5             2週間に1回       塾講師・家庭教師;営業・マーケティング                 いない
# 28            2週間に1回                    その他飲食店                 いない
# 30   ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 31               月1回                   カフェ;雑貨屋                 NaN
#
#    飲食店の情報はどこから仕入れることが多いですか？(複数選択可能)  \
# 3                      食べログ;Twitter
# 5                     Instagram;口コミ
# 28            Instagram;Twitter;口コミ
# 30           食べログ;Instagram;Twitter
# 31                  Instagram;雑誌;TV
#
#                           飲食店の情報はどこに保存していますか？(複数選択可能)  \
# 3   スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Twit...
# 5                   スクリーンショット;Instagramの「コレクション」や「投稿」
# 28  スクリーンショット;Instagramの「コレクション」や「投稿」;Twitterの「いいね...
# 30             スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」
# 31                  スクリーンショット;Instagramの「コレクション」や「投稿」
#
#    保存している飲食店に行くことはどれくらいありますか？ 気になった方に後日連絡するためにTwitterIDやLINEIDなどを教えてください。(任意)
# 3       実際にそこからお店に行くことはほとんどない                  @kajiguchi97 いつでもどうぞ。頑張ってください！
# 5                      2週間に1回                                             NaN
# 28                     月に1回程度                                             NaN
# 30                     月に1回程度                                             NaN
# 31                     2週間に1回                                        もりたまゆこ💞！

# %%
save_woman = woman_df[woman_df.iloc[:,2]=='はい']
non_save_woman = woman_df[woman_df.iloc[:,2]=='いいえ']

# %%
save_woman.head()
# Out:
#                          タイムスタンプ 性別を教えてください。  \
# 3   2018/10/18 10:54:56 午後 GMT+9           女
# 5   2018/10/18 10:55:12 午後 GMT+9           女
# 28  2018/10/18 11:05:04 午後 GMT+9           女
# 30  2018/10/18 11:05:15 午後 GMT+9           女
# 31  2018/10/18 11:05:17 午後 GMT+9           女
#
#    お気に入りの飲食店や行きたい飲食店の情報を何らかの方法でスマートフォン内に保存していますか？ 夜に外食する頻度を教えてください。  \
# 3                                              はい         それよりもすくない
# 5                                              はい             週1-2回
# 28                                             はい             週1-2回
# 30                                             はい            2週間に1回
# 31                                             はい             週1-2回
#
#    飲み会に行く頻度を教えてください。 バイトやインターンを教えてください(複数回答可能) 現在交際中の人はいますか？(任意回答)  \
# 3    ほとんど行かない / 行かない                  塾講師・家庭教師                  いる
# 5             2週間に1回       塾講師・家庭教師;営業・マーケティング                 いない
# 28            2週間に1回                    その他飲食店                 いない
# 30   ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 31               月1回                   カフェ;雑貨屋                 NaN
#
#    飲食店の情報はどこから仕入れることが多いですか？(複数選択可能)  \
# 3                      食べログ;Twitter
# 5                     Instagram;口コミ
# 28            Instagram;Twitter;口コミ
# 30           食べログ;Instagram;Twitter
# 31                  Instagram;雑誌;TV
#
#                           飲食店の情報はどこに保存していますか？(複数選択可能)  \
# 3   スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Twit...
# 5                   スクリーンショット;Instagramの「コレクション」や「投稿」
# 28  スクリーンショット;Instagramの「コレクション」や「投稿」;Twitterの「いいね...
# 30             スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」
# 31                  スクリーンショット;Instagramの「コレクション」や「投稿」
#
#    保存している飲食店に行くことはどれくらいありますか？ 気になった方に後日連絡するためにTwitterIDやLINEIDなどを教えてください。(任意)
# 3       実際にそこからお店に行くことはほとんどない                  @kajiguchi97 いつでもどうぞ。頑張ってください！
# 5                      2週間に1回                                             NaN
# 28                     月に1回程度                                             NaN
# 30                     月に1回程度                                             NaN
# 31                     2週間に1回                                        もりたまゆこ💞！

# %% [markdown]
# ## 外食する頻度

# %%
save_often = save_woman.iloc[:,3]
save_often_uniq = set(save_often)
save_often_data = np.zeros(len(save_often_uniq))
for (i, u) in enumerate(save_often_uniq):
    for s in save_often:
        if s == u:
            save_often_data[i] += 1

# %%
pie_chart(save_often_data, save_often_uniq)

# %%
non_save_often = non_save_woman.iloc[:,3]
non_save_often_data = np.zeros(len(save_often_uniq))
for (i, u) in enumerate(save_often_uniq):
    for s in non_save_often:
        if s == u:
            non_save_often_data[i] += 1

# %%
pie_chart(non_save_often_data, save_often_uniq)

# %% [markdown]
# そこまで差はない印象
#
# 週3以上外食する人は保存する傾向にある気がする

# %% [markdown]
# ## 飲み会に行く頻度

# %%
save_often_drink = save_woman.iloc[:,4]
save_often_drink_uniq = set(save_often_drink)
save_often_drink_data = np.zeros(len(save_often_drink_uniq))
for (i, u) in enumerate(save_often_drink_uniq):
    for s in save_often_drink:
        if s == u:
            save_often_drink_data[i] += 1
pie_chart(save_often_drink_data, save_often_drink_uniq)

# %%
non_save_often_drink = non_save_woman.iloc[:,4]
non_save_often_drink_data = np.zeros(len(save_often_drink_uniq))
for (i, u) in enumerate(save_often_drink_uniq):
    for s in non_save_often_drink:
        if s == u:
            non_save_often_drink_data[i] += 1
pie_chart(non_save_often_drink_data, save_often_drink_uniq)

# %% [markdown]
# これは割と差がある。
#
# 保存する人は飲む傾向にある。
#
# やっぱ保存してる人はチャラそう

# %% [markdown]
# ## 彼氏いるか

# %%
with_boyfriend_num = len(woman_df[woman_df.iloc[:,6]=='いる'])
without_boyfriend_num = len(woman_df[woman_df.iloc[:,6]=='いない'])
boyfriend_rate = with_boyfriend_num/(with_boyfriend_num+without_boyfriend_num) * 100
print("全体で彼氏いる率: {}%".format(boyfriend_rate))

save_with_boyfriend_num = len(save_woman[save_woman.iloc[:,6]=='いる'])
save_without_boyfriend_num = len(save_woman[save_woman.iloc[:,6]=='いない'])
save_boyfriend_rate = save_with_boyfriend_num/(save_with_boyfriend_num+save_without_boyfriend_num) * 100
print("保存してる人の中で彼氏いる率: {}%".format(save_boyfriend_rate))

non_save_with_boyfriend_num = len(non_save_woman[non_save_woman.iloc[:,6]=='いる'])
non_save_without_boyfriend_num = len(non_save_woman[non_save_woman.iloc[:,6]=='いない'])
non_save_boyfriend_rate = non_save_with_boyfriend_num/(non_save_with_boyfriend_num + non_save_without_boyfriend_num) * 100
print("保存してない人の中で彼氏いる率: {}%".format(non_save_boyfriend_rate))
# Out:
# 全体で彼氏いる率: 33.92857142857143%
# 保存してる人の中で彼氏いる率: 38.46153846153847%
# 保存してない人の中で彼氏いる率: 23.52941176470588%

# %% [markdown]
# やっぱり彼氏、彼女いる率と正相関ありそう。
#
# どっちが先かはわかんないけど

# %% [markdown]
# ## どんなバイトやってるか

# %%
woman_save_copy = woman_save.copy()

# %%
woman_save_copy = woman_save_copy.fillna('やっていない')

# %%
import collections
def flatten(l):
    for el in l:
        if isinstance(el, collections.Iterable) and not isinstance(el, (str, bytes)):
            yield from flatten(el)
        else:
            yield el

# %%
woman_df_copy = woman_df.fillna('やっていない')

# %%
job = [source.split(';') for source in woman_df_copy.iloc[:,5]]
job = list(flatten(job))

job_uniq = set(job)

# %%
save_job = list(flatten([source.split(';') for source in woman_save_copy.iloc[:,5]]))
job_uniq = set(job)
save_job_data = np.zeros(len(job_uniq))
for (i, s) in enumerate(job_uniq):
    for p in save_job:
        if p == s:
            save_job_data[i] += 1

pie_chart(save_job_data, job_uniq)

# %%
non_save_job = list(flatten([source.split(';') for source in non_save_woman.iloc[:,5]]))
non_save_data = np.zeros(len(job_uniq))
for (i, s) in enumerate(job_uniq):
    for p in non_save_job:
        if p == s:
            non_save_data[i] += 1
pie_chart(non_save_data, job_uniq)

# %% [markdown]
# カフェバイト率の圧倒的な違い
#
# 飲食バイトは保存してない方が率高い

# %% [markdown]
# 概して何となく確かに保存してる人はリア充な感じする

# %% [markdown]
# # 保存してる女の分析

# %% [markdown]
# ## 保存した店によく行く人

# %%
woman_save
# Out:
#                           タイムスタンプ 性別を教えてください。  \
# 3    2018/10/18 10:54:56 午後 GMT+9           女
# 5    2018/10/18 10:55:12 午後 GMT+9           女
# 28   2018/10/18 11:05:04 午後 GMT+9           女
# 30   2018/10/18 11:05:15 午後 GMT+9           女
# 31   2018/10/18 11:05:17 午後 GMT+9           女
# 33   2018/10/18 11:06:06 午後 GMT+9           女
# 34   2018/10/18 11:06:16 午後 GMT+9           女
# 37   2018/10/18 11:06:33 午後 GMT+9           女
# 38   2018/10/18 11:06:52 午後 GMT+9           女
# 41   2018/10/18 11:08:03 午後 GMT+9           女
# 42   2018/10/18 11:08:48 午後 GMT+9           女
# 46   2018/10/18 11:09:32 午後 GMT+9           女
# 48   2018/10/18 11:10:26 午後 GMT+9           女
# 52   2018/10/18 11:11:20 午後 GMT+9           女
# 53   2018/10/18 11:12:12 午後 GMT+9           女
# 56   2018/10/18 11:13:26 午後 GMT+9           女
# 61   2018/10/18 11:15:28 午後 GMT+9           女
# 68   2018/10/18 11:19:39 午後 GMT+9           女
# 75   2018/10/18 11:21:56 午後 GMT+9           女
# 78   2018/10/18 11:28:06 午後 GMT+9           女
# 79   2018/10/18 11:28:19 午後 GMT+9           女
# 82   2018/10/18 11:31:10 午後 GMT+9           女
# 86   2018/10/18 11:33:44 午後 GMT+9           女
# 88   2018/10/18 11:35:25 午後 GMT+9           女
# 105  2018/10/18 11:56:17 午後 GMT+9           女
# 112  2018/10/19 12:36:06 午前 GMT+9           女
# 113  2018/10/19 12:39:51 午前 GMT+9           女
# 114  2018/10/19 12:48:22 午前 GMT+9           女
# 124   2018/10/19 6:39:55 午前 GMT+9           女
# 130   2018/10/19 7:58:41 午前 GMT+9           女
# 138   2018/10/19 9:04:03 午前 GMT+9           女
# 142   2018/10/19 9:14:11 午前 GMT+9           女
# 162   2018/10/19 2:37:48 午後 GMT+9           女
# 163   2018/10/19 2:41:23 午後 GMT+9           女
# 164   2018/10/19 2:45:10 午後 GMT+9           女
# 166   2018/10/19 3:25:20 午後 GMT+9           女
# 167   2018/10/19 4:10:33 午後 GMT+9           女
# 173   2018/10/20 1:07:39 午前 GMT+9           女
# 177   2018/10/20 9:22:07 午後 GMT+9           女
# 179  2018/10/20 10:49:26 午後 GMT+9           女
#
#     お気に入りの飲食店や行きたい飲食店の情報を何らかの方法でスマートフォン内に保存していますか？ 夜に外食する頻度を教えてください。  \
# 3                                               はい         それよりもすくない
# 5                                               はい             週1-2回
# 28                                              はい             週1-2回
# 30                                              はい            2週間に1回
# 31                                              はい             週1-2回
# 33                                              はい             週1-2回
# 34                                              はい        3週間-1ヶ月に一回
# 37                                              はい         それよりもすくない
# 38                                              はい             週3-4回
# 41                                              はい             週1-2回
# 42                                              はい             週1-2回
# 46                                              はい             週1-2回
# 48                                              はい             週3-4回
# 52                                              はい             週5回以上
# 53                                              はい             週1-2回
# 56                                              はい             週1-2回
# 61                                              はい             週1-2回
# 68                                              はい             週1-2回
# 75                                              はい             週3-4回
# 78                                              はい             週5回以上
# 79                                              はい            2週間に1回
# 82                                              はい             週3-4回
# 86                                              はい            2週間に1回
# 88                                              はい            2週間に1回
# 105                                             はい             週1-2回
# 112                                             はい            2週間に1回
# 113                                             はい             週1-2回
# 114                                             はい            2週間に1回
# 124                                             はい             週3-4回
# 130                                             はい            2週間に1回
# 138                                             はい             週1-2回
# 142                                             はい        3週間-1ヶ月に一回
# 162                                             はい             週3-4回
# 163                                             はい             週5回以上
# 164                                             はい             週1-2回
# 166                                             はい             週3-4回
# 167                                             はい             週1-2回
# 173                                             はい             週5回以上
# 177                                             はい             週1-2回
# 179                                             はい             週1-2回
#
#     飲み会に行く頻度を教えてください。 バイトやインターンを教えてください(複数回答可能) 現在交際中の人はいますか？(任意回答)  \
# 3     ほとんど行かない / 行かない                  塾講師・家庭教師                  いる
# 5              2週間に1回       塾講師・家庭教師;営業・マーケティング                 いない
# 28             2週間に1回                    その他飲食店                 いない
# 30    ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 31                月1回                   カフェ;雑貨屋                 NaN
# 33              週1~2日           カフェ;エンジニア・デザイナー                 いない
# 34    ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 37    ほとんど行かない / 行かない                    やっていない                 いない
# 38              週1~2日       塾講師・家庭教師;営業・マーケティング                 いない
# 41              週1~2日              塾講師・家庭教師;カフェ                  いる
# 42    ほとんど行かない / 行かない                  塾講師・家庭教師                  いる
# 46                月1回                  塾講師・家庭教師                  いる
# 48                月1回                  塾講師・家庭教師                  いる
# 52                月1回                  塾講師・家庭教師                  いる
# 53              週1~2日                  塾講師・家庭教師                  いる
# 56                月1回                  塾講師・家庭教師                 いない
# 61              週1~2日                    やっていない                 いない
# 68                月1回         その他飲食店;営業・マーケティング                 いない
# 75                月1回                  塾講師・家庭教師                  いる
# 78             2週間に1回                  塾講師・家庭教師                 いない
# 79                月1回                    その他飲食店                 いない
# 82    ほとんど行かない / 行かない                    やっていない                 いない
# 86              週1~2日                        清掃                 いない
# 88                月1回                       カフェ                 いない
# 105               月1回              塾講師・家庭教師;カフェ                 いない
# 112               月1回                       NaN                 いない
# 113               月1回                  塾講師・家庭教師                  いる
# 114   ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 124               月1回    エンジニア・デザイナー;営業・マーケティング                 いない
# 130               月1回                  塾講師・家庭教師                  いる
# 138            2週間に1回                  カフェ;メンター                  いる
# 142   ほとんど行かない / 行かない                    塾受付、事務                 いない
# 162             週1~2日                       カフェ                  いる
# 163             週1~2日                       カフェ                 いない
# 164            2週間に1回            カフェ;営業・マーケティング                  いる
# 166            2週間に1回                  塾講師・家庭教師                 いない
# 167   ほとんど行かない / 行かない                       カフェ                  いる
# 173             週1~2日                       NaN                 いない
# 177               月1回                       カフェ                 いない
# 179             週1~2日                        翻訳                  いる
#
#                       飲食店の情報はどこから仕入れることが多いですか？(複数選択可能)  \
# 3                                         食べログ;Twitter
# 5                                        Instagram;口コミ
# 28                               Instagram;Twitter;口コミ
# 30                              食べログ;Instagram;Twitter
# 31                                     Instagram;雑誌;TV
# 33               食べログ;Instagram;Twitter;口コミ;ぐるなび;雑誌;TV
# 34                                     食べログ;Retty;ぐるなび
# 37            食べログ;Retty;Instagram;口コミ;Hot Pepper;ぐるなび
# 38                              食べログ;Instagram;Twitter
# 41                              Instagram;Twitter;ぐるなび
# 42                        食べログ;Twitter;Hot Pepper;ぐるなび
# 46                           食べログ;Instagram;Hot Pepper
# 48                                                食べログ
# 52                                       Instagram;口コミ
# 53                        食べログ;Retty;Instagram;ぐるなび;雑誌
# 56                             食べログ;Hot Pepper;ぐるなび;TV
# 61                食べログ;Retty;Instagram;Hot Pepper;ぐるなび
# 68                                      食べログ;Instagram
# 75                                  Twitter;Hot Pepper
# 78                              食べログ;Instagram;Twitter
# 79                   食べログ;Instagram;Twitter;Hot Pepper
# 82                                      食べログ;Instagram
# 86                                  Twitter;Hot Pepper
# 88                                  食べログ;Instagram;口コミ
# 105                  食べログ;Retty;Instagram;Twitter;ぐるなび
# 112                           食べログ;Twitter;口コミ;ぐるなび;TV
# 113                            Instagram;Twitter;TV;友人
# 114           食べログ;Retty;Instagram;Twitter;口コミ;ぐるなび;TV
# 124                     食べログ;Instagram;Twitter;ぐるなび;雑誌
# 130                                   食べログ;口コミ;ぐるなび;TV
# 138  食べログ;Instagram;口コミ;SafariやChromeなどのブラウザ;Hot Pe...
# 142                                         Twitter;一休
# 162       食べログ;Instagram;Twitter;Hot Pepper;ぐるなび;雑誌;TV
# 163  食べログ;Instagram;SafariやChromeなどのブラウザ;Hot Pepper...
# 164                                         食べログ;Retty
# 166                              食べログ;Instagram;口コミ;TV
# 167                             食べログ;Instagram;Twitter
# 173                                               食べログ
# 177                     Instagram;SafariやChromeなどのブラウザ
# 179                                  食べログ;Twitter;ぐるなび
#
#                            飲食店の情報はどこに保存していますか？(複数選択可能)  \
# 3    スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Twit...
# 5                    スクリーンショット;Instagramの「コレクション」や「投稿」
# 28   スクリーンショット;Instagramの「コレクション」や「投稿」;Twitterの「いいね...
# 30              スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」
# 31                   スクリーンショット;Instagramの「コレクション」や「投稿」
# 33   スクリーンショット;Instagramの「コレクション」や「投稿」;Twitterの「いいね...
# 34                                           スクリーンショット
# 37                                           スクリーンショット
# 38   スクリーンショット;Instagramの「コレクション」や「投稿」;Twitterの「いいね...
# 41   スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Inst...
# 42   スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」;Hot Pep...
# 46                   スクリーンショット;Instagramの「コレクション」や「投稿」
# 48                                    Safariのリーディングリスト
# 52   スクリーンショット;Instagramの「コレクション」や「投稿」;Twitterの「いいね...
# 53   スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Inst...
# 56                                           スクリーンショット
# 61                                           スクリーンショット
# 68                             Instagramの「コレクション」や「投稿」
# 75    Twitterの「いいね」や「ツイート」や「モーメント」;Hot Pepperの「ブックマーク」
# 78                             Instagramの「コレクション」や「投稿」
# 79                       スクリーンショット;Hot Pepperの「ブックマーク」
# 82                   スクリーンショット;Instagramの「コレクション」や「投稿」
# 86              スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」
# 88                   スクリーンショット;Instagramの「コレクション」や「投稿」
# 105                              スクリーンショット;食べログの「行きたい」
# 112             スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」
# 113                  スクリーンショット;Instagramの「コレクション」や「投稿」
# 114          スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など)
# 124                  スクリーンショット;Instagramの「コレクション」や「投稿」
# 130                                          スクリーンショット
# 138  スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Inst...
# 142                                          スクリーンショット
# 162                  スクリーンショット;Instagramの「コレクション」や「投稿」
# 163                                          スクリーンショット
# 164                                          スクリーンショット
# 166                            Instagramの「コレクション」や「投稿」
# 167                                        食べログの「行きたい」
# 173                                          スクリーンショット
# 177                                          スクリーンショット
# 179                                        食べログの「行きたい」
#
#     保存している飲食店に行くことはどれくらいありますか？ 気になった方に後日連絡するためにTwitterIDやLINEIDなどを教えてください。(任意)
# 3        実際にそこからお店に行くことはほとんどない                  @kajiguchi97 いつでもどうぞ。頑張ってください！
# 5                       2週間に1回                                             NaN
# 28                      月に1回程度                                             NaN
# 30                      月に1回程度                                             NaN
# 31                      2週間に1回                                        もりたまゆこ💞！
# 33                      月に1回程度                                             NaN
# 34                      月に1回程度                                             NaN
# 37       実際にそこからお店に行くことはほとんどない                                             NaN
# 38                      月に1回程度                                             NaN
# 41       実際にそこからお店に行くことはほとんどない                                             NaN
# 42                      月に1回程度                                             NaN
# 46                      2週間に1回                                             NaN
# 48       実際にそこからお店に行くことはほとんどない                                             NaN
# 52                      2週間に1回                                             NaN
# 53       実際にそこからお店に行くことはほとんどない                                             NaN
# 56       実際にそこからお店に行くことはほとんどない                                             NaN
# 61                      月に1回程度                                             NaN
# 68       実際にそこからお店に行くことはほとんどない                                             NaN
# 75                      月に1回程度                                             NaN
# 78       実際にそこからお店に行くことはほとんどない                                             NaN
# 79                      月に1回程度                                             NaN
# 82                      月に1回程度                                             NaN
# 86       実際にそこからお店に行くことはほとんどない                                             NaN
# 88       実際にそこからお店に行くことはほとんどない                                             NaN
# 105                     月に1回程度                                             NaN
# 112      実際にそこからお店に行くことはほとんどない                                             NaN
# 113                     2週間に1回                                             NaN
# 114                     月に1回程度                                             NaN
# 124                     月に1回程度                                             NaN
# 130      実際にそこからお店に行くことはほとんどない                                             NaN
# 138                      週1~2日                                        @yunapus
# 142                     月に1回程度                                             NaN
# 162                     2週間に1回                                             NaN
# 163                     月に1回程度                                    らいん:0432risa
# 164                     月に1回程度                                             NaN
# 166                     月に1回程度                                             NaN
# 167                     月に1回程度                                             NaN
# 173      実際にそこからお店に行くことはほとんどない                                             NaN
# 177      実際にそこからお店に行くことはほとんどない                                             NaN
# 179                      週1~2日                                    @maim__01257

# %%
pd.concat([woman_save[woman_save.iloc[:,9] == '2週間に1回'], woman_save[woman_save.iloc[:,9] == '週1~2日']], axis=0)
# Out:
#                           タイムスタンプ 性別を教えてください。  \
# 5    2018/10/18 10:55:12 午後 GMT+9           女
# 31   2018/10/18 11:05:17 午後 GMT+9           女
# 46   2018/10/18 11:09:32 午後 GMT+9           女
# 52   2018/10/18 11:11:20 午後 GMT+9           女
# 113  2018/10/19 12:39:51 午前 GMT+9           女
# 162   2018/10/19 2:37:48 午後 GMT+9           女
# 138   2018/10/19 9:04:03 午前 GMT+9           女
# 179  2018/10/20 10:49:26 午後 GMT+9           女
#
#     お気に入りの飲食店や行きたい飲食店の情報を何らかの方法でスマートフォン内に保存していますか？ 夜に外食する頻度を教えてください。  \
# 5                                               はい             週1-2回
# 31                                              はい             週1-2回
# 46                                              はい             週1-2回
# 52                                              はい             週5回以上
# 113                                             はい             週1-2回
# 162                                             はい             週3-4回
# 138                                             はい             週1-2回
# 179                                             はい             週1-2回
#
#     飲み会に行く頻度を教えてください。 バイトやインターンを教えてください(複数回答可能) 現在交際中の人はいますか？(任意回答)  \
# 5              2週間に1回       塾講師・家庭教師;営業・マーケティング                 いない
# 31                月1回                   カフェ;雑貨屋                 NaN
# 46                月1回                  塾講師・家庭教師                  いる
# 52                月1回                  塾講師・家庭教師                  いる
# 113               月1回                  塾講師・家庭教師                  いる
# 162             週1~2日                       カフェ                  いる
# 138            2週間に1回                  カフェ;メンター                  いる
# 179             週1~2日                        翻訳                  いる
#
#                       飲食店の情報はどこから仕入れることが多いですか？(複数選択可能)  \
# 5                                        Instagram;口コミ
# 31                                     Instagram;雑誌;TV
# 46                           食べログ;Instagram;Hot Pepper
# 52                                       Instagram;口コミ
# 113                            Instagram;Twitter;TV;友人
# 162       食べログ;Instagram;Twitter;Hot Pepper;ぐるなび;雑誌;TV
# 138  食べログ;Instagram;口コミ;SafariやChromeなどのブラウザ;Hot Pe...
# 179                                  食べログ;Twitter;ぐるなび
#
#                            飲食店の情報はどこに保存していますか？(複数選択可能)  \
# 5                    スクリーンショット;Instagramの「コレクション」や「投稿」
# 31                   スクリーンショット;Instagramの「コレクション」や「投稿」
# 46                   スクリーンショット;Instagramの「コレクション」や「投稿」
# 52   スクリーンショット;Instagramの「コレクション」や「投稿」;Twitterの「いいね...
# 113                  スクリーンショット;Instagramの「コレクション」や「投稿」
# 162                  スクリーンショット;Instagramの「コレクション」や「投稿」
# 138  スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Inst...
# 179                                        食べログの「行きたい」
#
#     保存している飲食店に行くことはどれくらいありますか？ 気になった方に後日連絡するためにTwitterIDやLINEIDなどを教えてください。(任意)
# 5                       2週間に1回                                             NaN
# 31                      2週間に1回                                        もりたまゆこ💞！
# 46                      2週間に1回                                             NaN
# 52                      2週間に1回                                             NaN
# 113                     2週間に1回                                             NaN
# 162                     2週間に1回                                             NaN
# 138                      週1~2日                                        @yunapus
# 179                      週1~2日                                    @maim__01257

# %% [markdown]
# これは熱い
#
# めっちゃ似てる！！！！！！！！！！！
#
# だいたい彼氏いる（森田もいる）
#
# プールはスクショとインスタが圧倒的に多い。
#
# ソースはインスタが主なのかな、多分

# %% [markdown]
# ## ソースが複数の人と一つの人

# %%
woman_save[np.array([len(source.split(';')) for source in woman_save.iloc[:,7]]) > 1]
# Out:
#                           タイムスタンプ 性別を教えてください。  \
# 3    2018/10/18 10:54:56 午後 GMT+9           女
# 5    2018/10/18 10:55:12 午後 GMT+9           女
# 28   2018/10/18 11:05:04 午後 GMT+9           女
# 30   2018/10/18 11:05:15 午後 GMT+9           女
# 31   2018/10/18 11:05:17 午後 GMT+9           女
# 33   2018/10/18 11:06:06 午後 GMT+9           女
# 34   2018/10/18 11:06:16 午後 GMT+9           女
# 37   2018/10/18 11:06:33 午後 GMT+9           女
# 38   2018/10/18 11:06:52 午後 GMT+9           女
# 41   2018/10/18 11:08:03 午後 GMT+9           女
# 42   2018/10/18 11:08:48 午後 GMT+9           女
# 46   2018/10/18 11:09:32 午後 GMT+9           女
# 52   2018/10/18 11:11:20 午後 GMT+9           女
# 53   2018/10/18 11:12:12 午後 GMT+9           女
# 56   2018/10/18 11:13:26 午後 GMT+9           女
# 61   2018/10/18 11:15:28 午後 GMT+9           女
# 68   2018/10/18 11:19:39 午後 GMT+9           女
# 75   2018/10/18 11:21:56 午後 GMT+9           女
# 78   2018/10/18 11:28:06 午後 GMT+9           女
# 79   2018/10/18 11:28:19 午後 GMT+9           女
# 82   2018/10/18 11:31:10 午後 GMT+9           女
# 86   2018/10/18 11:33:44 午後 GMT+9           女
# 88   2018/10/18 11:35:25 午後 GMT+9           女
# 105  2018/10/18 11:56:17 午後 GMT+9           女
# 112  2018/10/19 12:36:06 午前 GMT+9           女
# 113  2018/10/19 12:39:51 午前 GMT+9           女
# 114  2018/10/19 12:48:22 午前 GMT+9           女
# 124   2018/10/19 6:39:55 午前 GMT+9           女
# 130   2018/10/19 7:58:41 午前 GMT+9           女
# 138   2018/10/19 9:04:03 午前 GMT+9           女
# 142   2018/10/19 9:14:11 午前 GMT+9           女
# 162   2018/10/19 2:37:48 午後 GMT+9           女
# 163   2018/10/19 2:41:23 午後 GMT+9           女
# 164   2018/10/19 2:45:10 午後 GMT+9           女
# 166   2018/10/19 3:25:20 午後 GMT+9           女
# 167   2018/10/19 4:10:33 午後 GMT+9           女
# 177   2018/10/20 9:22:07 午後 GMT+9           女
# 179  2018/10/20 10:49:26 午後 GMT+9           女
#
#     お気に入りの飲食店や行きたい飲食店の情報を何らかの方法でスマートフォン内に保存していますか？ 夜に外食する頻度を教えてください。  \
# 3                                               はい         それよりもすくない
# 5                                               はい             週1-2回
# 28                                              はい             週1-2回
# 30                                              はい            2週間に1回
# 31                                              はい             週1-2回
# 33                                              はい             週1-2回
# 34                                              はい        3週間-1ヶ月に一回
# 37                                              はい         それよりもすくない
# 38                                              はい             週3-4回
# 41                                              はい             週1-2回
# 42                                              はい             週1-2回
# 46                                              はい             週1-2回
# 52                                              はい             週5回以上
# 53                                              はい             週1-2回
# 56                                              はい             週1-2回
# 61                                              はい             週1-2回
# 68                                              はい             週1-2回
# 75                                              はい             週3-4回
# 78                                              はい             週5回以上
# 79                                              はい            2週間に1回
# 82                                              はい             週3-4回
# 86                                              はい            2週間に1回
# 88                                              はい            2週間に1回
# 105                                             はい             週1-2回
# 112                                             はい            2週間に1回
# 113                                             はい             週1-2回
# 114                                             はい            2週間に1回
# 124                                             はい             週3-4回
# 130                                             はい            2週間に1回
# 138                                             はい             週1-2回
# 142                                             はい        3週間-1ヶ月に一回
# 162                                             はい             週3-4回
# 163                                             はい             週5回以上
# 164                                             はい             週1-2回
# 166                                             はい             週3-4回
# 167                                             はい             週1-2回
# 177                                             はい             週1-2回
# 179                                             はい             週1-2回
#
#     飲み会に行く頻度を教えてください。 バイトやインターンを教えてください(複数回答可能) 現在交際中の人はいますか？(任意回答)  \
# 3     ほとんど行かない / 行かない                  塾講師・家庭教師                  いる
# 5              2週間に1回       塾講師・家庭教師;営業・マーケティング                 いない
# 28             2週間に1回                    その他飲食店                 いない
# 30    ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 31                月1回                   カフェ;雑貨屋                 NaN
# 33              週1~2日           カフェ;エンジニア・デザイナー                 いない
# 34    ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 37    ほとんど行かない / 行かない                    やっていない                 いない
# 38              週1~2日       塾講師・家庭教師;営業・マーケティング                 いない
# 41              週1~2日              塾講師・家庭教師;カフェ                  いる
# 42    ほとんど行かない / 行かない                  塾講師・家庭教師                  いる
# 46                月1回                  塾講師・家庭教師                  いる
# 52                月1回                  塾講師・家庭教師                  いる
# 53              週1~2日                  塾講師・家庭教師                  いる
# 56                月1回                  塾講師・家庭教師                 いない
# 61              週1~2日                    やっていない                 いない
# 68                月1回         その他飲食店;営業・マーケティング                 いない
# 75                月1回                  塾講師・家庭教師                  いる
# 78             2週間に1回                  塾講師・家庭教師                 いない
# 79                月1回                    その他飲食店                 いない
# 82    ほとんど行かない / 行かない                    やっていない                 いない
# 86              週1~2日                        清掃                 いない
# 88                月1回                       カフェ                 いない
# 105               月1回              塾講師・家庭教師;カフェ                 いない
# 112               月1回                       NaN                 いない
# 113               月1回                  塾講師・家庭教師                  いる
# 114   ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 124               月1回    エンジニア・デザイナー;営業・マーケティング                 いない
# 130               月1回                  塾講師・家庭教師                  いる
# 138            2週間に1回                  カフェ;メンター                  いる
# 142   ほとんど行かない / 行かない                    塾受付、事務                 いない
# 162             週1~2日                       カフェ                  いる
# 163             週1~2日                       カフェ                 いない
# 164            2週間に1回            カフェ;営業・マーケティング                  いる
# 166            2週間に1回                  塾講師・家庭教師                 いない
# 167   ほとんど行かない / 行かない                       カフェ                  いる
# 177               月1回                       カフェ                 いない
# 179             週1~2日                        翻訳                  いる
#
#                       飲食店の情報はどこから仕入れることが多いですか？(複数選択可能)  \
# 3                                         食べログ;Twitter
# 5                                        Instagram;口コミ
# 28                               Instagram;Twitter;口コミ
# 30                              食べログ;Instagram;Twitter
# 31                                     Instagram;雑誌;TV
# 33               食べログ;Instagram;Twitter;口コミ;ぐるなび;雑誌;TV
# 34                                     食べログ;Retty;ぐるなび
# 37            食べログ;Retty;Instagram;口コミ;Hot Pepper;ぐるなび
# 38                              食べログ;Instagram;Twitter
# 41                              Instagram;Twitter;ぐるなび
# 42                        食べログ;Twitter;Hot Pepper;ぐるなび
# 46                           食べログ;Instagram;Hot Pepper
# 52                                       Instagram;口コミ
# 53                        食べログ;Retty;Instagram;ぐるなび;雑誌
# 56                             食べログ;Hot Pepper;ぐるなび;TV
# 61                食べログ;Retty;Instagram;Hot Pepper;ぐるなび
# 68                                      食べログ;Instagram
# 75                                  Twitter;Hot Pepper
# 78                              食べログ;Instagram;Twitter
# 79                   食べログ;Instagram;Twitter;Hot Pepper
# 82                                      食べログ;Instagram
# 86                                  Twitter;Hot Pepper
# 88                                  食べログ;Instagram;口コミ
# 105                  食べログ;Retty;Instagram;Twitter;ぐるなび
# 112                           食べログ;Twitter;口コミ;ぐるなび;TV
# 113                            Instagram;Twitter;TV;友人
# 114           食べログ;Retty;Instagram;Twitter;口コミ;ぐるなび;TV
# 124                     食べログ;Instagram;Twitter;ぐるなび;雑誌
# 130                                   食べログ;口コミ;ぐるなび;TV
# 138  食べログ;Instagram;口コミ;SafariやChromeなどのブラウザ;Hot Pe...
# 142                                         Twitter;一休
# 162       食べログ;Instagram;Twitter;Hot Pepper;ぐるなび;雑誌;TV
# 163  食べログ;Instagram;SafariやChromeなどのブラウザ;Hot Pepper...
# 164                                         食べログ;Retty
# 166                              食べログ;Instagram;口コミ;TV
# 167                             食べログ;Instagram;Twitter
# 177                     Instagram;SafariやChromeなどのブラウザ
# 179                                  食べログ;Twitter;ぐるなび
#
#                            飲食店の情報はどこに保存していますか？(複数選択可能)  \
# 3    スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Twit...
# 5                    スクリーンショット;Instagramの「コレクション」や「投稿」
# 28   スクリーンショット;Instagramの「コレクション」や「投稿」;Twitterの「いいね...
# 30              スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」
# 31                   スクリーンショット;Instagramの「コレクション」や「投稿」
# 33   スクリーンショット;Instagramの「コレクション」や「投稿」;Twitterの「いいね...
# 34                                           スクリーンショット
# 37                                           スクリーンショット
# 38   スクリーンショット;Instagramの「コレクション」や「投稿」;Twitterの「いいね...
# 41   スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Inst...
# 42   スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」;Hot Pep...
# 46                   スクリーンショット;Instagramの「コレクション」や「投稿」
# 52   スクリーンショット;Instagramの「コレクション」や「投稿」;Twitterの「いいね...
# 53   スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Inst...
# 56                                           スクリーンショット
# 61                                           スクリーンショット
# 68                             Instagramの「コレクション」や「投稿」
# 75    Twitterの「いいね」や「ツイート」や「モーメント」;Hot Pepperの「ブックマーク」
# 78                             Instagramの「コレクション」や「投稿」
# 79                       スクリーンショット;Hot Pepperの「ブックマーク」
# 82                   スクリーンショット;Instagramの「コレクション」や「投稿」
# 86              スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」
# 88                   スクリーンショット;Instagramの「コレクション」や「投稿」
# 105                              スクリーンショット;食べログの「行きたい」
# 112             スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」
# 113                  スクリーンショット;Instagramの「コレクション」や「投稿」
# 114          スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など)
# 124                  スクリーンショット;Instagramの「コレクション」や「投稿」
# 130                                          スクリーンショット
# 138  スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Inst...
# 142                                          スクリーンショット
# 162                  スクリーンショット;Instagramの「コレクション」や「投稿」
# 163                                          スクリーンショット
# 164                                          スクリーンショット
# 166                            Instagramの「コレクション」や「投稿」
# 167                                        食べログの「行きたい」
# 177                                          スクリーンショット
# 179                                        食べログの「行きたい」
#
#     保存している飲食店に行くことはどれくらいありますか？ 気になった方に後日連絡するためにTwitterIDやLINEIDなどを教えてください。(任意)
# 3        実際にそこからお店に行くことはほとんどない                  @kajiguchi97 いつでもどうぞ。頑張ってください！
# 5                       2週間に1回                                             NaN
# 28                      月に1回程度                                             NaN
# 30                      月に1回程度                                             NaN
# 31                      2週間に1回                                        もりたまゆこ💞！
# 33                      月に1回程度                                             NaN
# 34                      月に1回程度                                             NaN
# 37       実際にそこからお店に行くことはほとんどない                                             NaN
# 38                      月に1回程度                                             NaN
# 41       実際にそこからお店に行くことはほとんどない                                             NaN
# 42                      月に1回程度                                             NaN
# 46                      2週間に1回                                             NaN
# 52                      2週間に1回                                             NaN
# 53       実際にそこからお店に行くことはほとんどない                                             NaN
# 56       実際にそこからお店に行くことはほとんどない                                             NaN
# 61                      月に1回程度                                             NaN
# 68       実際にそこからお店に行くことはほとんどない                                             NaN
# 75                      月に1回程度                                             NaN
# 78       実際にそこからお店に行くことはほとんどない                                             NaN
# 79                      月に1回程度                                             NaN
# 82                      月に1回程度                                             NaN
# 86       実際にそこからお店に行くことはほとんどない                                             NaN
# 88       実際にそこからお店に行くことはほとんどない                                             NaN
# 105                     月に1回程度                                             NaN
# 112      実際にそこからお店に行くことはほとんどない                                             NaN
# 113                     2週間に1回                                             NaN
# 114                     月に1回程度                                             NaN
# 124                     月に1回程度                                             NaN
# 130      実際にそこからお店に行くことはほとんどない                                             NaN
# 138                      週1~2日                                        @yunapus
# 142                     月に1回程度                                             NaN
# 162                     2週間に1回                                             NaN
# 163                     月に1回程度                                    らいん:0432risa
# 164                     月に1回程度                                             NaN
# 166                     月に1回程度                                             NaN
# 167                     月に1回程度                                             NaN
# 177      実際にそこからお店に行くことはほとんどない                                             NaN
# 179                      週1~2日                                    @maim__01257

# %%
woman_save[np.array([len(source.split(';')) for source in woman_save.iloc[:,7]]) < 2]
# Out:
#                           タイムスタンプ 性別を教えてください。  \
# 48   2018/10/18 11:10:26 午後 GMT+9           女
# 173   2018/10/20 1:07:39 午前 GMT+9           女
#
#     お気に入りの飲食店や行きたい飲食店の情報を何らかの方法でスマートフォン内に保存していますか？ 夜に外食する頻度を教えてください。  \
# 48                                              はい             週3-4回
# 173                                             はい             週5回以上
#
#     飲み会に行く頻度を教えてください。 バイトやインターンを教えてください(複数回答可能) 現在交際中の人はいますか？(任意回答)  \
# 48                月1回                  塾講師・家庭教師                  いる
# 173             週1~2日                       NaN                 いない
#
#     飲食店の情報はどこから仕入れることが多いですか？(複数選択可能) 飲食店の情報はどこに保存していますか？(複数選択可能)  \
# 48                              食べログ            Safariのリーディングリスト
# 173                             食べログ                   スクリーンショット
#
#     保存している飲食店に行くことはどれくらいありますか？ 気になった方に後日連絡するためにTwitterIDやLINEIDなどを教えてください。(任意)
# 48       実際にそこからお店に行くことはほとんどない                                             NaN
# 173      実際にそこからお店に行くことはほとんどない                                             NaN

# %% [markdown]
# ## 保存先が複数の人と一つの人

# %%
woman_save[np.array([len(pool.split(';')) for pool in woman_save.iloc[:,8]]) > 1]
# Out:
#                           タイムスタンプ 性別を教えてください。  \
# 3    2018/10/18 10:54:56 午後 GMT+9           女
# 5    2018/10/18 10:55:12 午後 GMT+9           女
# 28   2018/10/18 11:05:04 午後 GMT+9           女
# 30   2018/10/18 11:05:15 午後 GMT+9           女
# 31   2018/10/18 11:05:17 午後 GMT+9           女
# 33   2018/10/18 11:06:06 午後 GMT+9           女
# 38   2018/10/18 11:06:52 午後 GMT+9           女
# 41   2018/10/18 11:08:03 午後 GMT+9           女
# 42   2018/10/18 11:08:48 午後 GMT+9           女
# 46   2018/10/18 11:09:32 午後 GMT+9           女
# 52   2018/10/18 11:11:20 午後 GMT+9           女
# 53   2018/10/18 11:12:12 午後 GMT+9           女
# 75   2018/10/18 11:21:56 午後 GMT+9           女
# 79   2018/10/18 11:28:19 午後 GMT+9           女
# 82   2018/10/18 11:31:10 午後 GMT+9           女
# 86   2018/10/18 11:33:44 午後 GMT+9           女
# 88   2018/10/18 11:35:25 午後 GMT+9           女
# 105  2018/10/18 11:56:17 午後 GMT+9           女
# 112  2018/10/19 12:36:06 午前 GMT+9           女
# 113  2018/10/19 12:39:51 午前 GMT+9           女
# 114  2018/10/19 12:48:22 午前 GMT+9           女
# 124   2018/10/19 6:39:55 午前 GMT+9           女
# 138   2018/10/19 9:04:03 午前 GMT+9           女
# 162   2018/10/19 2:37:48 午後 GMT+9           女
#
#     お気に入りの飲食店や行きたい飲食店の情報を何らかの方法でスマートフォン内に保存していますか？ 夜に外食する頻度を教えてください。  \
# 3                                               はい         それよりもすくない
# 5                                               はい             週1-2回
# 28                                              はい             週1-2回
# 30                                              はい            2週間に1回
# 31                                              はい             週1-2回
# 33                                              はい             週1-2回
# 38                                              はい             週3-4回
# 41                                              はい             週1-2回
# 42                                              はい             週1-2回
# 46                                              はい             週1-2回
# 52                                              はい             週5回以上
# 53                                              はい             週1-2回
# 75                                              はい             週3-4回
# 79                                              はい            2週間に1回
# 82                                              はい             週3-4回
# 86                                              はい            2週間に1回
# 88                                              はい            2週間に1回
# 105                                             はい             週1-2回
# 112                                             はい            2週間に1回
# 113                                             はい             週1-2回
# 114                                             はい            2週間に1回
# 124                                             はい             週3-4回
# 138                                             はい             週1-2回
# 162                                             はい             週3-4回
#
#     飲み会に行く頻度を教えてください。 バイトやインターンを教えてください(複数回答可能) 現在交際中の人はいますか？(任意回答)  \
# 3     ほとんど行かない / 行かない                  塾講師・家庭教師                  いる
# 5              2週間に1回       塾講師・家庭教師;営業・マーケティング                 いない
# 28             2週間に1回                    その他飲食店                 いない
# 30    ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 31                月1回                   カフェ;雑貨屋                 NaN
# 33              週1~2日           カフェ;エンジニア・デザイナー                 いない
# 38              週1~2日       塾講師・家庭教師;営業・マーケティング                 いない
# 41              週1~2日              塾講師・家庭教師;カフェ                  いる
# 42    ほとんど行かない / 行かない                  塾講師・家庭教師                  いる
# 46                月1回                  塾講師・家庭教師                  いる
# 52                月1回                  塾講師・家庭教師                  いる
# 53              週1~2日                  塾講師・家庭教師                  いる
# 75                月1回                  塾講師・家庭教師                  いる
# 79                月1回                    その他飲食店                 いない
# 82    ほとんど行かない / 行かない                    やっていない                 いない
# 86              週1~2日                        清掃                 いない
# 88                月1回                       カフェ                 いない
# 105               月1回              塾講師・家庭教師;カフェ                 いない
# 112               月1回                       NaN                 いない
# 113               月1回                  塾講師・家庭教師                  いる
# 114   ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 124               月1回    エンジニア・デザイナー;営業・マーケティング                 いない
# 138            2週間に1回                  カフェ;メンター                  いる
# 162             週1~2日                       カフェ                  いる
#
#                       飲食店の情報はどこから仕入れることが多いですか？(複数選択可能)  \
# 3                                         食べログ;Twitter
# 5                                        Instagram;口コミ
# 28                               Instagram;Twitter;口コミ
# 30                              食べログ;Instagram;Twitter
# 31                                     Instagram;雑誌;TV
# 33               食べログ;Instagram;Twitter;口コミ;ぐるなび;雑誌;TV
# 38                              食べログ;Instagram;Twitter
# 41                              Instagram;Twitter;ぐるなび
# 42                        食べログ;Twitter;Hot Pepper;ぐるなび
# 46                           食べログ;Instagram;Hot Pepper
# 52                                       Instagram;口コミ
# 53                        食べログ;Retty;Instagram;ぐるなび;雑誌
# 75                                  Twitter;Hot Pepper
# 79                   食べログ;Instagram;Twitter;Hot Pepper
# 82                                      食べログ;Instagram
# 86                                  Twitter;Hot Pepper
# 88                                  食べログ;Instagram;口コミ
# 105                  食べログ;Retty;Instagram;Twitter;ぐるなび
# 112                           食べログ;Twitter;口コミ;ぐるなび;TV
# 113                            Instagram;Twitter;TV;友人
# 114           食べログ;Retty;Instagram;Twitter;口コミ;ぐるなび;TV
# 124                     食べログ;Instagram;Twitter;ぐるなび;雑誌
# 138  食べログ;Instagram;口コミ;SafariやChromeなどのブラウザ;Hot Pe...
# 162       食べログ;Instagram;Twitter;Hot Pepper;ぐるなび;雑誌;TV
#
#                            飲食店の情報はどこに保存していますか？(複数選択可能)  \
# 3    スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Twit...
# 5                    スクリーンショット;Instagramの「コレクション」や「投稿」
# 28   スクリーンショット;Instagramの「コレクション」や「投稿」;Twitterの「いいね...
# 30              スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」
# 31                   スクリーンショット;Instagramの「コレクション」や「投稿」
# 33   スクリーンショット;Instagramの「コレクション」や「投稿」;Twitterの「いいね...
# 38   スクリーンショット;Instagramの「コレクション」や「投稿」;Twitterの「いいね...
# 41   スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Inst...
# 42   スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」;Hot Pep...
# 46                   スクリーンショット;Instagramの「コレクション」や「投稿」
# 52   スクリーンショット;Instagramの「コレクション」や「投稿」;Twitterの「いいね...
# 53   スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Inst...
# 75    Twitterの「いいね」や「ツイート」や「モーメント」;Hot Pepperの「ブックマーク」
# 79                       スクリーンショット;Hot Pepperの「ブックマーク」
# 82                   スクリーンショット;Instagramの「コレクション」や「投稿」
# 86              スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」
# 88                   スクリーンショット;Instagramの「コレクション」や「投稿」
# 105                              スクリーンショット;食べログの「行きたい」
# 112             スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」
# 113                  スクリーンショット;Instagramの「コレクション」や「投稿」
# 114          スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など)
# 124                  スクリーンショット;Instagramの「コレクション」や「投稿」
# 138  スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Inst...
# 162                  スクリーンショット;Instagramの「コレクション」や「投稿」
#
#     保存している飲食店に行くことはどれくらいありますか？ 気になった方に後日連絡するためにTwitterIDやLINEIDなどを教えてください。(任意)
# 3        実際にそこからお店に行くことはほとんどない                  @kajiguchi97 いつでもどうぞ。頑張ってください！
# 5                       2週間に1回                                             NaN
# 28                      月に1回程度                                             NaN
# 30                      月に1回程度                                             NaN
# 31                      2週間に1回                                        もりたまゆこ💞！
# 33                      月に1回程度                                             NaN
# 38                      月に1回程度                                             NaN
# 41       実際にそこからお店に行くことはほとんどない                                             NaN
# 42                      月に1回程度                                             NaN
# 46                      2週間に1回                                             NaN
# 52                      2週間に1回                                             NaN
# 53       実際にそこからお店に行くことはほとんどない                                             NaN
# 75                      月に1回程度                                             NaN
# 79                      月に1回程度                                             NaN
# 82                      月に1回程度                                             NaN
# 86       実際にそこからお店に行くことはほとんどない                                             NaN
# 88       実際にそこからお店に行くことはほとんどない                                             NaN
# 105                     月に1回程度                                             NaN
# 112      実際にそこからお店に行くことはほとんどない                                             NaN
# 113                     2週間に1回                                             NaN
# 114                     月に1回程度                                             NaN
# 124                     月に1回程度                                             NaN
# 138                      週1~2日                                        @yunapus
# 162                     2週間に1回                                             NaN

# %%
woman_save[np.array([len(pool.split(';')) for pool in woman_save.iloc[:,8]]) < 2]
# Out:
#                           タイムスタンプ 性別を教えてください。  \
# 34   2018/10/18 11:06:16 午後 GMT+9           女
# 37   2018/10/18 11:06:33 午後 GMT+9           女
# 48   2018/10/18 11:10:26 午後 GMT+9           女
# 56   2018/10/18 11:13:26 午後 GMT+9           女
# 61   2018/10/18 11:15:28 午後 GMT+9           女
# 68   2018/10/18 11:19:39 午後 GMT+9           女
# 78   2018/10/18 11:28:06 午後 GMT+9           女
# 130   2018/10/19 7:58:41 午前 GMT+9           女
# 142   2018/10/19 9:14:11 午前 GMT+9           女
# 163   2018/10/19 2:41:23 午後 GMT+9           女
# 164   2018/10/19 2:45:10 午後 GMT+9           女
# 166   2018/10/19 3:25:20 午後 GMT+9           女
# 167   2018/10/19 4:10:33 午後 GMT+9           女
# 173   2018/10/20 1:07:39 午前 GMT+9           女
# 177   2018/10/20 9:22:07 午後 GMT+9           女
# 179  2018/10/20 10:49:26 午後 GMT+9           女
#
#     お気に入りの飲食店や行きたい飲食店の情報を何らかの方法でスマートフォン内に保存していますか？ 夜に外食する頻度を教えてください。  \
# 34                                              はい        3週間-1ヶ月に一回
# 37                                              はい         それよりもすくない
# 48                                              はい             週3-4回
# 56                                              はい             週1-2回
# 61                                              はい             週1-2回
# 68                                              はい             週1-2回
# 78                                              はい             週5回以上
# 130                                             はい            2週間に1回
# 142                                             はい        3週間-1ヶ月に一回
# 163                                             はい             週5回以上
# 164                                             はい             週1-2回
# 166                                             はい             週3-4回
# 167                                             はい             週1-2回
# 173                                             はい             週5回以上
# 177                                             はい             週1-2回
# 179                                             はい             週1-2回
#
#     飲み会に行く頻度を教えてください。 バイトやインターンを教えてください(複数回答可能) 現在交際中の人はいますか？(任意回答)  \
# 34    ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 37    ほとんど行かない / 行かない                    やっていない                 いない
# 48                月1回                  塾講師・家庭教師                  いる
# 56                月1回                  塾講師・家庭教師                 いない
# 61              週1~2日                    やっていない                 いない
# 68                月1回         その他飲食店;営業・マーケティング                 いない
# 78             2週間に1回                  塾講師・家庭教師                 いない
# 130               月1回                  塾講師・家庭教師                  いる
# 142   ほとんど行かない / 行かない                    塾受付、事務                 いない
# 163             週1~2日                       カフェ                 いない
# 164            2週間に1回            カフェ;営業・マーケティング                  いる
# 166            2週間に1回                  塾講師・家庭教師                 いない
# 167   ほとんど行かない / 行かない                       カフェ                  いる
# 173             週1~2日                       NaN                 いない
# 177               月1回                       カフェ                 いない
# 179             週1~2日                        翻訳                  いる
#
#                       飲食店の情報はどこから仕入れることが多いですか？(複数選択可能)  \
# 34                                     食べログ;Retty;ぐるなび
# 37            食べログ;Retty;Instagram;口コミ;Hot Pepper;ぐるなび
# 48                                                食べログ
# 56                             食べログ;Hot Pepper;ぐるなび;TV
# 61                食べログ;Retty;Instagram;Hot Pepper;ぐるなび
# 68                                      食べログ;Instagram
# 78                              食べログ;Instagram;Twitter
# 130                                   食べログ;口コミ;ぐるなび;TV
# 142                                         Twitter;一休
# 163  食べログ;Instagram;SafariやChromeなどのブラウザ;Hot Pepper...
# 164                                         食べログ;Retty
# 166                              食べログ;Instagram;口コミ;TV
# 167                             食べログ;Instagram;Twitter
# 173                                               食べログ
# 177                     Instagram;SafariやChromeなどのブラウザ
# 179                                  食べログ;Twitter;ぐるなび
#
#     飲食店の情報はどこに保存していますか？(複数選択可能) 保存している飲食店に行くことはどれくらいありますか？  \
# 34                    スクリーンショット                     月に1回程度
# 37                    スクリーンショット      実際にそこからお店に行くことはほとんどない
# 48             Safariのリーディングリスト      実際にそこからお店に行くことはほとんどない
# 56                    スクリーンショット      実際にそこからお店に行くことはほとんどない
# 61                    スクリーンショット                     月に1回程度
# 68      Instagramの「コレクション」や「投稿」      実際にそこからお店に行くことはほとんどない
# 78      Instagramの「コレクション」や「投稿」      実際にそこからお店に行くことはほとんどない
# 130                   スクリーンショット      実際にそこからお店に行くことはほとんどない
# 142                   スクリーンショット                     月に1回程度
# 163                   スクリーンショット                     月に1回程度
# 164                   スクリーンショット                     月に1回程度
# 166     Instagramの「コレクション」や「投稿」                     月に1回程度
# 167                 食べログの「行きたい」                     月に1回程度
# 173                   スクリーンショット      実際にそこからお店に行くことはほとんどない
# 177                   スクリーンショット      実際にそこからお店に行くことはほとんどない
# 179                 食べログの「行きたい」                      週1~2日
#
#     気になった方に後日連絡するためにTwitterIDやLINEIDなどを教えてください。(任意)
# 34                                              NaN
# 37                                              NaN
# 48                                              NaN
# 56                                              NaN
# 61                                              NaN
# 68                                              NaN
# 78                                              NaN
# 130                                             NaN
# 142                                             NaN
# 163                                    らいん:0432risa
# 164                                             NaN
# 166                                             NaN
# 167                                             NaN
# 173                                             NaN
# 177                                             NaN
# 179                                    @maim__01257

# %% [markdown]
# # 保存してる男の分析

# %% [markdown]
# ## 保存した店によく行く人

# %%
pd.concat([man_save[man_save.iloc[:,9] == '2週間に1回'], man_save[man_save.iloc[:,9] == '週1~2日']], axis=0)
# Out:
#                           タイムスタンプ 性別を教えてください。  \
# 67   2018/10/18 11:19:30 午後 GMT+9           男
# 74   2018/10/18 11:21:29 午後 GMT+9           男
# 90   2018/10/18 11:37:36 午後 GMT+9           男
# 92   2018/10/18 11:38:13 午後 GMT+9           男
# 102  2018/10/18 11:51:58 午後 GMT+9           男
# 116  2018/10/19 12:57:53 午前 GMT+9           男
# 123   2018/10/19 5:42:24 午前 GMT+9           男
# 156  2018/10/19 12:59:35 午後 GMT+9           男
# 159   2018/10/19 1:33:31 午後 GMT+9           男
# 169   2018/10/19 5:07:15 午後 GMT+9           男
# 36   2018/10/18 11:06:32 午後 GMT+9           男
# 126   2018/10/19 6:55:49 午前 GMT+9           男
# 158   2018/10/19 1:32:26 午後 GMT+9           男
#
#     お気に入りの飲食店や行きたい飲食店の情報を何らかの方法でスマートフォン内に保存していますか？ 夜に外食する頻度を教えてください。  \
# 67                                              はい             週1-2回
# 74                                              はい             週1-2回
# 90                                              はい             週1-2回
# 92                                              はい         それよりもすくない
# 102                                             はい             週5回以上
# 116                                             はい             週1-2回
# 123                                             はい             週3-4回
# 156                                             はい             週1-2回
# 159                                             はい             週3-4回
# 169                                             はい            2週間に1回
# 36                                              はい             週1-2回
# 126                                             はい             週1-2回
# 158                                             はい             週3-4回
#
#     飲み会に行く頻度を教えてください。   バイトやインターンを教えてください(複数回答可能) 現在交際中の人はいますか？(任意回答)  \
# 67                月1回                    塾講師・家庭教師                  いる
# 74                月1回  塾講師・家庭教師;営業・マーケティング;記事ライター                  いる
# 90                月1回                    塾講師・家庭教師                  いる
# 92    ほとんど行かない / 行かない                      やっていない                 いない
# 102            2週間に1回        塾講師・家庭教師;エンジニア・デザイナー                  いる
# 116             週1~2日        塾講師・家庭教師;エンジニア・デザイナー                 いない
# 123             週1~2日                    リーガルサービス                  いる
# 156               月1回                    塾講師・家庭教師                  いる
# 159            2週間に1回                    塾講師・家庭教師                 いない
# 169            2週間に1回                    塾講師・家庭教師                 いない
# 36                月1回                      その他飲食店                 NaN
# 126            2週間に1回                    塾講師・家庭教師                 いない
# 158             週1~2日        エンジニア・デザイナー;ライター・編集者                 いない
#
#                       飲食店の情報はどこから仕入れることが多いですか？(複数選択可能)  \
# 67                                 食べログ;Twitter;口コミ;TV
# 74                                   Instagram;retrip
# 90                                  食べログ;Retty;Twitter
# 92                                                食べログ
# 102                                               食べログ
# 116                             Instagram;口コミ;TV;ネット検索
# 123                                               食べログ
# 156  食べログ;Instagram;Twitter;口コミ;SafariやChromeなどのブラウ...
# 159                               食べログ;Retty;Instagram
# 169  食べログ;Instagram;口コミ;SafariやChromeなどのブラウザ;Hot Pe...
# 36                           食べログ;口コミ;雑誌;TV;Google Map
# 126    食べログ;Retty;Instagram;Twitter;Hot Pepper;ぐるなび;TV
# 158                             食べログ;Retty;TV;TERIYAKI
#
#                            飲食店の情報はどこに保存していますか？(複数選択可能)  \
# 67                               スクリーンショット;食べログの「行きたい」
# 74                                         retripの保存機能
# 90                               スクリーンショット;食べログの「行きたい」
# 92                                         食べログの「行きたい」
# 102                                        食べログの「行きたい」
# 116                    メモアプリ(「iPhoneのメモ」、「Evernote」など)
# 123                                        食べログの「行きたい」
# 156  メモアプリ(「iPhoneのメモ」、「Evernote」など);Twitterの「いいね」や...
# 159      スクリーンショット;食べログの「行きたい」;Instagramの「コレクション」や「投稿」
# 169                                          スクリーンショット
# 36                                          Google Map
# 126                                          スクリーンショット
# 158                                 Googleマップ(行きたいリスト)
#
#     保存している飲食店に行くことはどれくらいありますか？ 気になった方に後日連絡するためにTwitterIDやLINEIDなどを教えてください。(任意)
# 67                      2週間に1回                                             NaN
# 74                      2週間に1回                                        スペの石井だよ。
# 90                      2週間に1回                                             NaN
# 92                      2週間に1回                                             NaN
# 102                     2週間に1回                                             NaN
# 116                     2週間に1回                                             NaN
# 123                     2週間に1回                                             NaN
# 156                     2週間に1回                                             NaN
# 159                     2週間に1回                                        decers_9
# 169                     2週間に1回                                             NaN
# 36                       週1~2日                                             NaN
# 126                      週1~2日                                             NaN
# 158                      週1~2日                                     @user_id_us

# %% [markdown]
# ## ソースが複数の人と一つの人

# %%
man_save[np.array([len(source.split(';')) for source in man_save.iloc[:,7]]) > 1]
# Out:
#                           タイムスタンプ 性別を教えてください。  \
# 1    2018/10/18 10:54:09 午後 GMT+9           男
# 10   2018/10/18 10:59:10 午後 GMT+9           男
# 15   2018/10/18 11:01:38 午後 GMT+9           男
# 18   2018/10/18 11:01:56 午後 GMT+9           男
# 20   2018/10/18 11:02:55 午後 GMT+9           男
# 29   2018/10/18 11:05:06 午後 GMT+9           男
# 32   2018/10/18 11:05:21 午後 GMT+9           男
# 35   2018/10/18 11:06:24 午後 GMT+9           男
# 36   2018/10/18 11:06:32 午後 GMT+9           男
# 45   2018/10/18 11:09:26 午後 GMT+9           男
# 47   2018/10/18 11:09:54 午後 GMT+9           男
# 49   2018/10/18 11:10:55 午後 GMT+9           男
# 62   2018/10/18 11:15:34 午後 GMT+9           男
# 65   2018/10/18 11:17:45 午後 GMT+9           男
# 66   2018/10/18 11:18:05 午後 GMT+9           男
# 67   2018/10/18 11:19:30 午後 GMT+9           男
# 70   2018/10/18 11:20:34 午後 GMT+9           男
# 72   2018/10/18 11:21:05 午後 GMT+9           男
# 74   2018/10/18 11:21:29 午後 GMT+9           男
# 85   2018/10/18 11:33:39 午後 GMT+9           男
# 90   2018/10/18 11:37:36 午後 GMT+9           男
# 106  2018/10/18 11:57:44 午後 GMT+9           男
# 108  2018/10/19 12:08:42 午前 GMT+9           男
# 116  2018/10/19 12:57:53 午前 GMT+9           男
# 118   2018/10/19 1:05:07 午前 GMT+9           男
# 126   2018/10/19 6:55:49 午前 GMT+9           男
# 131   2018/10/19 8:10:00 午前 GMT+9           男
# 146   2018/10/19 9:34:56 午前 GMT+9           男
# 149  2018/10/19 10:30:42 午前 GMT+9           男
# 156  2018/10/19 12:59:35 午後 GMT+9           男
# 158   2018/10/19 1:32:26 午後 GMT+9           男
# 159   2018/10/19 1:33:31 午後 GMT+9           男
# 168   2018/10/19 5:04:05 午後 GMT+9           男
# 169   2018/10/19 5:07:15 午後 GMT+9           男
# 170   2018/10/19 5:21:07 午後 GMT+9           男
#
#     お気に入りの飲食店や行きたい飲食店の情報を何らかの方法でスマートフォン内に保存していますか？ 夜に外食する頻度を教えてください。  \
# 1                                               はい             週1-2回
# 10                                              はい            2週間に1回
# 15                                              はい             週3-4回
# 18                                              はい             週1-2回
# 20                                              はい             週1-2回
# 29                                              はい             週1-2回
# 32                                              はい             週1-2回
# 35                                              はい             週1-2回
# 36                                              はい             週1-2回
# 45                                              はい             週1-2回
# 47                                              はい            2週間に1回
# 49                                              はい             週1-2回
# 62                                              はい            2週間に1回
# 65                                              はい             週3-4回
# 66                                              はい             週1-2回
# 67                                              はい             週1-2回
# 70                                              はい             週1-2回
# 72                                              はい             週1-2回
# 74                                              はい             週1-2回
# 85                                              はい             週1-2回
# 90                                              はい             週1-2回
# 106                                             はい             週1-2回
# 108                                             はい             週3-4回
# 116                                             はい             週1-2回
# 118                                             はい             週1-2回
# 126                                             はい             週1-2回
# 131                                             はい        3週間-1ヶ月に一回
# 146                                             はい             週1-2回
# 149                                             はい             週1-2回
# 156                                             はい             週1-2回
# 158                                             はい             週3-4回
# 159                                             はい             週3-4回
# 168                                             はい             週5回以上
# 169                                             はい            2週間に1回
# 170                                             はい             週5回以上
#
#     飲み会に行く頻度を教えてください。   バイトやインターンを教えてください(複数回答可能) 現在交際中の人はいますか？(任意回答)  \
# 1     ほとんど行かない / 行かない                    塾講師・家庭教師                 いない
# 10             2週間に1回                         NaN                 いない
# 15                月1回                          採点                 いない
# 18    ほとんど行かない / 行かない                      やっていない                  いる
# 20             2週間に1回                  営業・マーケティング                 いない
# 29                月1回                    塾講師・家庭教師                 NaN
# 32    ほとんど行かない / 行かない        塾講師・家庭教師;エンジニア・デザイナー                 いない
# 35                月1回        塾講師・家庭教師;エンジニア・デザイナー                  いる
# 36                月1回                      その他飲食店                 NaN
# 45                月1回                    塾講師・家庭教師                 いない
# 47                月1回                    塾講師・家庭教師                  いる
# 49              週3日以上  塾講師・家庭教師;その他飲食店;営業・マーケティング                  いる
# 62             2週間に1回             塾講師・家庭教師;その他飲食店                 いない
# 65             2週間に1回                 エンジニア・デザイナー                  いる
# 66                月1回                      その他飲食店                 いない
# 67                月1回                    塾講師・家庭教師                  いる
# 70    ほとんど行かない / 行かない                    塾講師・家庭教師                  いる
# 72              週1~2日              塾講師・家庭教師;家電量販店                 いない
# 74                月1回  塾講師・家庭教師;営業・マーケティング;記事ライター                  いる
# 85             2週間に1回                    塾講師・家庭教師                 NaN
# 90                月1回                    塾講師・家庭教師                  いる
# 106   ほとんど行かない / 行かない             塾講師・家庭教師;その他飲食店                  いる
# 108               月1回                 エンジニア・デザイナー                 いない
# 116             週1~2日        塾講師・家庭教師;エンジニア・デザイナー                 いない
# 118               月1回                 エンジニア・デザイナー                  いる
# 126            2週間に1回                    塾講師・家庭教師                 いない
# 131   ほとんど行かない / 行かない                         NaN                 いない
# 146            2週間に1回                  営業・マーケティング                  いる
# 149   ほとんど行かない / 行かない                   その他飲食店;案内                 いない
# 156               月1回                    塾講師・家庭教師                  いる
# 158             週1~2日        エンジニア・デザイナー;ライター・編集者                 いない
# 159            2週間に1回                    塾講師・家庭教師                 いない
# 168            2週間に1回                 エンジニア・デザイナー                  いる
# 169            2週間に1回                    塾講師・家庭教師                 いない
# 170             週1~2日                 エンジニア・デザイナー                  いる
#
#                       飲食店の情報はどこから仕入れることが多いですか？(複数選択可能)  \
# 1                                      食べログ;Hot Pepper
# 10                               食べログ;Twitter;口コミ;plat
# 15                                     食べログ;Twitter;TV
# 18                                           食べログ;ぐるなび
# 20                               Instagram;Twitter;口コミ
# 29                                    食べログ;Twitter;口コミ
# 32                          食べログ;Instagram;Twitter;口コミ
# 35                                        食べログ;ニュースアプリ
# 36                           食べログ;口コミ;雑誌;TV;Google Map
# 45                        食べログ;Twitter;Hot Pepper;ぐるなび
# 47                                    Twitter;口コミ;ぐるなび
# 49                  食べログ;Instagram;口コミ;Hot Pepper;ぐるなび
# 62                           食べログ;Instagram;Hot Pepper
# 65   食べログ;Retty;Instagram;Twitter;口コミ;Hot Pepper;ぐる...
# 66                                     食べログ;Hot Pepper
# 67                                 食べログ;Twitter;口コミ;TV
# 70                           食べログ;Instagram;Twitter;TV
# 72                          食べログ;Instagram;Twitter;口コミ
# 74                                   Instagram;retrip
# 85                                          食べログ;Retty
# 90                                  食べログ;Retty;Twitter
# 106                                     食べログ;Instagram
# 108                                           食べログ;口コミ
# 116                             Instagram;口コミ;TV;ネット検索
# 118                                          食べログ;ぐるなび
# 126    食べログ;Retty;Instagram;Twitter;Hot Pepper;ぐるなび;TV
# 131                                          食べログ;ぐるなび
# 146            食べログ;Instagram;口コミ;SafariやChromeなどのブラウザ
# 149                                   食べログ;Twitter;口コミ
# 156  食べログ;Instagram;Twitter;口コミ;SafariやChromeなどのブラウ...
# 158                             食べログ;Retty;TV;TERIYAKI
# 159                               食べログ;Retty;Instagram
# 168          Instagram;SafariやChromeなどのブラウザ;Hot Pepper
# 169  食べログ;Instagram;口コミ;SafariやChromeなどのブラウザ;Hot Pe...
# 170                             食べログ;Twitter;口コミ;雑誌;TV
#
#                            飲食店の情報はどこに保存していますか？(複数選択可能)  \
# 1                                                  NaN
# 10                                                   脳
# 15              スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」
# 18                                           スクリーンショット
# 20                                     スクリーンショット;お気に入り
# 29                                           スクリーンショット
# 32   メモアプリ(「iPhoneのメモ」、「Evernote」など);Twitterの「いいね」や...
# 35         メモアプリ(「iPhoneのメモ」、「Evernote」など);食べログの「行きたい」
# 36                                          Google Map
# 45                                           スクリーンショット
# 47                                    Safariでページを開いておく
# 49                     メモアプリ(「iPhoneのメモ」、「Evernote」など)
# 62                     メモアプリ(「iPhoneのメモ」、「Evernote」など)
# 65   スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Twit...
# 66    メモアプリ(「iPhoneのメモ」、「Evernote」など);safariのリーディングリスト
# 67                               スクリーンショット;食べログの「行きたい」
# 70   スクリーンショット;食べログの「行きたい」;Twitterの「いいね」や「ツイート」や「モー...
# 72   スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Twit...
# 74                                         retripの保存機能
# 85                                         食べログの「行きたい」
# 90                               スクリーンショット;食べログの「行きたい」
# 106                              スクリーンショット;食べログの「行きたい」
# 108                                         GoogleMaps
# 116                    メモアプリ(「iPhoneのメモ」、「Evernote」など)
# 118                             食べログの「行きたい」;google map
# 126                                          スクリーンショット
# 131                                          スクリーンショット
# 146                                        食べログの「行きたい」
# 149                                          スクリーンショット
# 156  メモアプリ(「iPhoneのメモ」、「Evernote」など);Twitterの「いいね」や...
# 158                                 Googleマップ(行きたいリスト)
# 159      スクリーンショット;食べログの「行きたい」;Instagramの「コレクション」や「投稿」
# 168     スクリーンショット;SafariやChromeなどのブラウザの「ブックマーク」や「タブ」など
# 169                                          スクリーンショット
# 170                                         google map
#
#     保存している飲食店に行くことはどれくらいありますか？ 気になった方に後日連絡するためにTwitterIDやLINEIDなどを教えてください。(任意)
# 1                      特に保存しない                                             NaN
# 10       実際にそこからお店に行くことはほとんどない                                         ディズニー行こ
# 15       実際にそこからお店に行くことはほとんどない                                             NaN
# 18                      月に1回程度                                             NaN
# 20       実際にそこからお店に行くことはほとんどない                                             NaN
# 29                      月に1回程度                                             NaN
# 32       実際にそこからお店に行くことはほとんどない                                             NaN
# 35                      月に1回程度                                             NaN
# 36                       週1~2日                                             NaN
# 45                      月に1回程度                                             NaN
# 47                      月に1回程度                                             NaN
# 49       実際にそこからお店に行くことはほとんどない                                             NaN
# 62       実際にそこからお店に行くことはほとんどない                                       kaito.a27
# 65                      月に1回程度                                             NaN
# 66                      月に1回程度                                             NaN
# 67                      2週間に1回                                             NaN
# 70                      月に1回程度                                             NaN
# 72       実際にそこからお店に行くことはほとんどない                                             NaN
# 74                      2週間に1回                                        スペの石井だよ。
# 85                      月に1回程度                                             NaN
# 90                      2週間に1回                                             NaN
# 106                     月に1回程度                                             NaN
# 108      実際にそこからお店に行くことはほとんどない                                             NaN
# 116                     2週間に1回                                             NaN
# 118                     月に1回程度                                    alkso42_8h2o
# 126                      週1~2日                                             NaN
# 131      実際にそこからお店に行くことはほとんどない                                             NaN
# 146      実際にそこからお店に行くことはほとんどない                                             NaN
# 149                     月に1回程度                                             NaN
# 156                     2週間に1回                                             NaN
# 158                      週1~2日                                     @user_id_us
# 159                     2週間に1回                                        decers_9
# 168      実際にそこからお店に行くことはほとんどない                                             NaN
# 169                     2週間に1回                                             NaN
# 170      実際にそこからお店に行くことはほとんどない                                      @sub_agent

# %%
man_save[np.array([len(source.split(';')) for source in man_save.iloc[:,7]]) < 2]
# Out:
#                           タイムスタンプ 性別を教えてください。  \
# 16   2018/10/18 11:01:41 午後 GMT+9           男
# 23   2018/10/18 11:04:01 午後 GMT+9           男
# 69   2018/10/18 11:20:12 午後 GMT+9           男
# 77   2018/10/18 11:27:57 午後 GMT+9           男
# 92   2018/10/18 11:38:13 午後 GMT+9           男
# 95   2018/10/18 11:41:55 午後 GMT+9           男
# 102  2018/10/18 11:51:58 午後 GMT+9           男
# 107  2018/10/18 11:59:31 午後 GMT+9           男
# 123   2018/10/19 5:42:24 午前 GMT+9           男
# 140   2018/10/19 9:05:38 午前 GMT+9           男
# 154  2018/10/19 12:27:12 午後 GMT+9           男
#
#     お気に入りの飲食店や行きたい飲食店の情報を何らかの方法でスマートフォン内に保存していますか？ 夜に外食する頻度を教えてください。  \
# 16                                              はい             週5回以上
# 23                                              はい            2週間に1回
# 69                                              はい             週3-4回
# 77                                              はい             週3-4回
# 92                                              はい         それよりもすくない
# 95                                              はい             週3-4回
# 102                                             はい             週5回以上
# 107                                             はい             週1-2回
# 123                                             はい             週3-4回
# 140                                             はい            2週間に1回
# 154                                             はい        3週間-1ヶ月に一回
#
#     飲み会に行く頻度を教えてください。 バイトやインターンを教えてください(複数回答可能) 現在交際中の人はいますか？(任意回答)  \
# 16                月1回                  塾講師・家庭教師                  いる
# 23                月1回      塾講師・家庭教師;エンジニア・デザイナー                 いない
# 69              週1~2日       塾講師・家庭教師;営業・マーケティング                  いる
# 77    ほとんど行かない / 行かない               エンジニア・デザイナー                  いる
# 92    ほとんど行かない / 行かない                    やっていない                 いない
# 95              週1~2日               エンジニア・デザイナー                  いる
# 102            2週間に1回      塾講師・家庭教師;エンジニア・デザイナー                  いる
# 107               月1回                    その他飲食店                 いない
# 123             週1~2日                  リーガルサービス                  いる
# 140   ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 154               月1回                        販売                 いない
#
#     飲食店の情報はどこから仕入れることが多いですか？(複数選択可能) 飲食店の情報はどこに保存していますか？(複数選択可能)  \
# 16                               口コミ                   スクリーンショット
# 23                              食べログ                    evernote
# 69        google 例)香川 うどん おすすめ等で調べると                   スクリーンショット
# 77                              食べログ                 食べログの「行きたい」
# 92                              食べログ                 食べログの「行きたい」
# 95                              食べログ                 食べログの「行きたい」
# 102                             食べログ                 食べログの「行きたい」
# 107                             食べログ                   スクリーンショット
# 123                             食べログ                 食べログの「行きたい」
# 140                              口コミ                   スクリーンショット
# 154                             食べログ                   スクリーンショット
#
#     保存している飲食店に行くことはどれくらいありますか？ 気になった方に後日連絡するためにTwitterIDやLINEIDなどを教えてください。(任意)
# 16       実際にそこからお店に行くことはほとんどない                            稲津です。必要なら中本から連絡ください。
# 23       実際にそこからお店に行くことはほとんどない                                             NaN
# 69                      月に1回程度                                             NaN
# 77       実際にそこからお店に行くことはほとんどない                                        kakenman
# 92                      2週間に1回                                             NaN
# 95                      月に1回程度                                        上田、自分で回答
# 102                     2週間に1回                                             NaN
# 107      実際にそこからお店に行くことはほとんどない                                             NaN
# 123                     2週間に1回                                             NaN
# 140      実際にそこからお店に行くことはほとんどない                                             NaN
# 154                     月に1回程度                                             NaN

# %% [markdown]
# ## 保存先が複数の人と一つの人

# %%
man_save.dropna(subset=['飲食店の情報はどこに保存していますか？(複数選択可能)'])[np.array([len(pool.split(';')) for pool in man_save.copy().dropna(subset=['飲食店の情報はどこに保存していますか？(複数選択可能)']).iloc[:,8]]) > 1]
# Out:
#                           タイムスタンプ 性別を教えてください。  \
# 15   2018/10/18 11:01:38 午後 GMT+9           男
# 20   2018/10/18 11:02:55 午後 GMT+9           男
# 32   2018/10/18 11:05:21 午後 GMT+9           男
# 35   2018/10/18 11:06:24 午後 GMT+9           男
# 65   2018/10/18 11:17:45 午後 GMT+9           男
# 66   2018/10/18 11:18:05 午後 GMT+9           男
# 67   2018/10/18 11:19:30 午後 GMT+9           男
# 70   2018/10/18 11:20:34 午後 GMT+9           男
# 72   2018/10/18 11:21:05 午後 GMT+9           男
# 90   2018/10/18 11:37:36 午後 GMT+9           男
# 106  2018/10/18 11:57:44 午後 GMT+9           男
# 118   2018/10/19 1:05:07 午前 GMT+9           男
# 156  2018/10/19 12:59:35 午後 GMT+9           男
# 159   2018/10/19 1:33:31 午後 GMT+9           男
# 168   2018/10/19 5:04:05 午後 GMT+9           男
#
#     お気に入りの飲食店や行きたい飲食店の情報を何らかの方法でスマートフォン内に保存していますか？ 夜に外食する頻度を教えてください。  \
# 15                                              はい             週3-4回
# 20                                              はい             週1-2回
# 32                                              はい             週1-2回
# 35                                              はい             週1-2回
# 65                                              はい             週3-4回
# 66                                              はい             週1-2回
# 67                                              はい             週1-2回
# 70                                              はい             週1-2回
# 72                                              はい             週1-2回
# 90                                              はい             週1-2回
# 106                                             はい             週1-2回
# 118                                             はい             週1-2回
# 156                                             はい             週1-2回
# 159                                             はい             週3-4回
# 168                                             はい             週5回以上
#
#     飲み会に行く頻度を教えてください。 バイトやインターンを教えてください(複数回答可能) 現在交際中の人はいますか？(任意回答)  \
# 15                月1回                        採点                 いない
# 20             2週間に1回                営業・マーケティング                 いない
# 32    ほとんど行かない / 行かない      塾講師・家庭教師;エンジニア・デザイナー                 いない
# 35                月1回      塾講師・家庭教師;エンジニア・デザイナー                  いる
# 65             2週間に1回               エンジニア・デザイナー                  いる
# 66                月1回                    その他飲食店                 いない
# 67                月1回                  塾講師・家庭教師                  いる
# 70    ほとんど行かない / 行かない                  塾講師・家庭教師                  いる
# 72              週1~2日            塾講師・家庭教師;家電量販店                 いない
# 90                月1回                  塾講師・家庭教師                  いる
# 106   ほとんど行かない / 行かない           塾講師・家庭教師;その他飲食店                  いる
# 118               月1回               エンジニア・デザイナー                  いる
# 156               月1回                  塾講師・家庭教師                  いる
# 159            2週間に1回                  塾講師・家庭教師                 いない
# 168            2週間に1回               エンジニア・デザイナー                  いる
#
#                       飲食店の情報はどこから仕入れることが多いですか？(複数選択可能)  \
# 15                                     食べログ;Twitter;TV
# 20                               Instagram;Twitter;口コミ
# 32                          食べログ;Instagram;Twitter;口コミ
# 35                                        食べログ;ニュースアプリ
# 65   食べログ;Retty;Instagram;Twitter;口コミ;Hot Pepper;ぐる...
# 66                                     食べログ;Hot Pepper
# 67                                 食べログ;Twitter;口コミ;TV
# 70                           食べログ;Instagram;Twitter;TV
# 72                          食べログ;Instagram;Twitter;口コミ
# 90                                  食べログ;Retty;Twitter
# 106                                     食べログ;Instagram
# 118                                          食べログ;ぐるなび
# 156  食べログ;Instagram;Twitter;口コミ;SafariやChromeなどのブラウ...
# 159                               食べログ;Retty;Instagram
# 168          Instagram;SafariやChromeなどのブラウザ;Hot Pepper
#
#                            飲食店の情報はどこに保存していますか？(複数選択可能)  \
# 15              スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」
# 20                                     スクリーンショット;お気に入り
# 32   メモアプリ(「iPhoneのメモ」、「Evernote」など);Twitterの「いいね」や...
# 35         メモアプリ(「iPhoneのメモ」、「Evernote」など);食べログの「行きたい」
# 65   スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Twit...
# 66    メモアプリ(「iPhoneのメモ」、「Evernote」など);safariのリーディングリスト
# 67                               スクリーンショット;食べログの「行きたい」
# 70   スクリーンショット;食べログの「行きたい」;Twitterの「いいね」や「ツイート」や「モー...
# 72   スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Twit...
# 90                               スクリーンショット;食べログの「行きたい」
# 106                              スクリーンショット;食べログの「行きたい」
# 118                             食べログの「行きたい」;google map
# 156  メモアプリ(「iPhoneのメモ」、「Evernote」など);Twitterの「いいね」や...
# 159      スクリーンショット;食べログの「行きたい」;Instagramの「コレクション」や「投稿」
# 168     スクリーンショット;SafariやChromeなどのブラウザの「ブックマーク」や「タブ」など
#
#     保存している飲食店に行くことはどれくらいありますか？ 気になった方に後日連絡するためにTwitterIDやLINEIDなどを教えてください。(任意)
# 15       実際にそこからお店に行くことはほとんどない                                             NaN
# 20       実際にそこからお店に行くことはほとんどない                                             NaN
# 32       実際にそこからお店に行くことはほとんどない                                             NaN
# 35                      月に1回程度                                             NaN
# 65                      月に1回程度                                             NaN
# 66                      月に1回程度                                             NaN
# 67                      2週間に1回                                             NaN
# 70                      月に1回程度                                             NaN
# 72       実際にそこからお店に行くことはほとんどない                                             NaN
# 90                      2週間に1回                                             NaN
# 106                     月に1回程度                                             NaN
# 118                     月に1回程度                                    alkso42_8h2o
# 156                     2週間に1回                                             NaN
# 159                     2週間に1回                                        decers_9
# 168      実際にそこからお店に行くことはほとんどない                                             NaN

# %%
man_save.dropna(subset=['飲食店の情報はどこに保存していますか？(複数選択可能)'])[np.array([len(pool.split(';')) for pool in man_save.copy().dropna(subset=['飲食店の情報はどこに保存していますか？(複数選択可能)']).iloc[:,8]]) < 2]
# Out:
#                           タイムスタンプ 性別を教えてください。  \
# 10   2018/10/18 10:59:10 午後 GMT+9           男
# 16   2018/10/18 11:01:41 午後 GMT+9           男
# 18   2018/10/18 11:01:56 午後 GMT+9           男
# 23   2018/10/18 11:04:01 午後 GMT+9           男
# 29   2018/10/18 11:05:06 午後 GMT+9           男
# 36   2018/10/18 11:06:32 午後 GMT+9           男
# 45   2018/10/18 11:09:26 午後 GMT+9           男
# 47   2018/10/18 11:09:54 午後 GMT+9           男
# 49   2018/10/18 11:10:55 午後 GMT+9           男
# 62   2018/10/18 11:15:34 午後 GMT+9           男
# 69   2018/10/18 11:20:12 午後 GMT+9           男
# 74   2018/10/18 11:21:29 午後 GMT+9           男
# 77   2018/10/18 11:27:57 午後 GMT+9           男
# 85   2018/10/18 11:33:39 午後 GMT+9           男
# 92   2018/10/18 11:38:13 午後 GMT+9           男
# 95   2018/10/18 11:41:55 午後 GMT+9           男
# 102  2018/10/18 11:51:58 午後 GMT+9           男
# 107  2018/10/18 11:59:31 午後 GMT+9           男
# 108  2018/10/19 12:08:42 午前 GMT+9           男
# 116  2018/10/19 12:57:53 午前 GMT+9           男
# 123   2018/10/19 5:42:24 午前 GMT+9           男
# 126   2018/10/19 6:55:49 午前 GMT+9           男
# 131   2018/10/19 8:10:00 午前 GMT+9           男
# 140   2018/10/19 9:05:38 午前 GMT+9           男
# 146   2018/10/19 9:34:56 午前 GMT+9           男
# 149  2018/10/19 10:30:42 午前 GMT+9           男
# 154  2018/10/19 12:27:12 午後 GMT+9           男
# 158   2018/10/19 1:32:26 午後 GMT+9           男
# 169   2018/10/19 5:07:15 午後 GMT+9           男
# 170   2018/10/19 5:21:07 午後 GMT+9           男
#
#     お気に入りの飲食店や行きたい飲食店の情報を何らかの方法でスマートフォン内に保存していますか？ 夜に外食する頻度を教えてください。  \
# 10                                              はい            2週間に1回
# 16                                              はい             週5回以上
# 18                                              はい             週1-2回
# 23                                              はい            2週間に1回
# 29                                              はい             週1-2回
# 36                                              はい             週1-2回
# 45                                              はい             週1-2回
# 47                                              はい            2週間に1回
# 49                                              はい             週1-2回
# 62                                              はい            2週間に1回
# 69                                              はい             週3-4回
# 74                                              はい             週1-2回
# 77                                              はい             週3-4回
# 85                                              はい             週1-2回
# 92                                              はい         それよりもすくない
# 95                                              はい             週3-4回
# 102                                             はい             週5回以上
# 107                                             はい             週1-2回
# 108                                             はい             週3-4回
# 116                                             はい             週1-2回
# 123                                             はい             週3-4回
# 126                                             はい             週1-2回
# 131                                             はい        3週間-1ヶ月に一回
# 140                                             はい            2週間に1回
# 146                                             はい             週1-2回
# 149                                             はい             週1-2回
# 154                                             はい        3週間-1ヶ月に一回
# 158                                             はい             週3-4回
# 169                                             はい            2週間に1回
# 170                                             はい             週5回以上
#
#     飲み会に行く頻度を教えてください。   バイトやインターンを教えてください(複数回答可能) 現在交際中の人はいますか？(任意回答)  \
# 10             2週間に1回                         NaN                 いない
# 16                月1回                    塾講師・家庭教師                  いる
# 18    ほとんど行かない / 行かない                      やっていない                  いる
# 23                月1回        塾講師・家庭教師;エンジニア・デザイナー                 いない
# 29                月1回                    塾講師・家庭教師                 NaN
# 36                月1回                      その他飲食店                 NaN
# 45                月1回                    塾講師・家庭教師                 いない
# 47                月1回                    塾講師・家庭教師                  いる
# 49              週3日以上  塾講師・家庭教師;その他飲食店;営業・マーケティング                  いる
# 62             2週間に1回             塾講師・家庭教師;その他飲食店                 いない
# 69              週1~2日         塾講師・家庭教師;営業・マーケティング                  いる
# 74                月1回  塾講師・家庭教師;営業・マーケティング;記事ライター                  いる
# 77    ほとんど行かない / 行かない                 エンジニア・デザイナー                  いる
# 85             2週間に1回                    塾講師・家庭教師                 NaN
# 92    ほとんど行かない / 行かない                      やっていない                 いない
# 95              週1~2日                 エンジニア・デザイナー                  いる
# 102            2週間に1回        塾講師・家庭教師;エンジニア・デザイナー                  いる
# 107               月1回                      その他飲食店                 いない
# 108               月1回                 エンジニア・デザイナー                 いない
# 116             週1~2日        塾講師・家庭教師;エンジニア・デザイナー                 いない
# 123             週1~2日                    リーガルサービス                  いる
# 126            2週間に1回                    塾講師・家庭教師                 いない
# 131   ほとんど行かない / 行かない                         NaN                 いない
# 140   ほとんど行かない / 行かない                    塾講師・家庭教師                 いない
# 146            2週間に1回                  営業・マーケティング                  いる
# 149   ほとんど行かない / 行かない                   その他飲食店;案内                 いない
# 154               月1回                          販売                 いない
# 158             週1~2日        エンジニア・デザイナー;ライター・編集者                 いない
# 169            2週間に1回                    塾講師・家庭教師                 いない
# 170             週1~2日                 エンジニア・デザイナー                  いる
#
#                       飲食店の情報はどこから仕入れることが多いですか？(複数選択可能)  \
# 10                               食べログ;Twitter;口コミ;plat
# 16                                                 口コミ
# 18                                           食べログ;ぐるなび
# 23                                                食べログ
# 29                                    食べログ;Twitter;口コミ
# 36                           食べログ;口コミ;雑誌;TV;Google Map
# 45                        食べログ;Twitter;Hot Pepper;ぐるなび
# 47                                    Twitter;口コミ;ぐるなび
# 49                  食べログ;Instagram;口コミ;Hot Pepper;ぐるなび
# 62                           食べログ;Instagram;Hot Pepper
# 69                          google 例)香川 うどん おすすめ等で調べると
# 74                                   Instagram;retrip
# 77                                                食べログ
# 85                                          食べログ;Retty
# 92                                                食べログ
# 95                                                食べログ
# 102                                               食べログ
# 107                                               食べログ
# 108                                           食べログ;口コミ
# 116                             Instagram;口コミ;TV;ネット検索
# 123                                               食べログ
# 126    食べログ;Retty;Instagram;Twitter;Hot Pepper;ぐるなび;TV
# 131                                          食べログ;ぐるなび
# 140                                                口コミ
# 146            食べログ;Instagram;口コミ;SafariやChromeなどのブラウザ
# 149                                   食べログ;Twitter;口コミ
# 154                                               食べログ
# 158                             食べログ;Retty;TV;TERIYAKI
# 169  食べログ;Instagram;口コミ;SafariやChromeなどのブラウザ;Hot Pe...
# 170                             食べログ;Twitter;口コミ;雑誌;TV
#
#          飲食店の情報はどこに保存していますか？(複数選択可能) 保存している飲食店に行くことはどれくらいありますか？  \
# 10                                 脳      実際にそこからお店に行くことはほとんどない
# 16                         スクリーンショット      実際にそこからお店に行くことはほとんどない
# 18                         スクリーンショット                     月に1回程度
# 23                          evernote      実際にそこからお店に行くことはほとんどない
# 29                         スクリーンショット                     月に1回程度
# 36                        Google Map                      週1~2日
# 45                         スクリーンショット                     月に1回程度
# 47                  Safariでページを開いておく                     月に1回程度
# 49   メモアプリ(「iPhoneのメモ」、「Evernote」など)      実際にそこからお店に行くことはほとんどない
# 62   メモアプリ(「iPhoneのメモ」、「Evernote」など)      実際にそこからお店に行くことはほとんどない
# 69                         スクリーンショット                     月に1回程度
# 74                       retripの保存機能                     2週間に1回
# 77                       食べログの「行きたい」      実際にそこからお店に行くことはほとんどない
# 85                       食べログの「行きたい」                     月に1回程度
# 92                       食べログの「行きたい」                     2週間に1回
# 95                       食べログの「行きたい」                     月に1回程度
# 102                      食べログの「行きたい」                     2週間に1回
# 107                        スクリーンショット      実際にそこからお店に行くことはほとんどない
# 108                       GoogleMaps      実際にそこからお店に行くことはほとんどない
# 116  メモアプリ(「iPhoneのメモ」、「Evernote」など)                     2週間に1回
# 123                      食べログの「行きたい」                     2週間に1回
# 126                        スクリーンショット                      週1~2日
# 131                        スクリーンショット      実際にそこからお店に行くことはほとんどない
# 140                        スクリーンショット      実際にそこからお店に行くことはほとんどない
# 146                      食べログの「行きたい」      実際にそこからお店に行くことはほとんどない
# 149                        スクリーンショット                     月に1回程度
# 154                        スクリーンショット                     月に1回程度
# 158               Googleマップ(行きたいリスト)                      週1~2日
# 169                        スクリーンショット                     2週間に1回
# 170                       google map      実際にそこからお店に行くことはほとんどない
#
#     気になった方に後日連絡するためにTwitterIDやLINEIDなどを教えてください。(任意)
# 10                                          ディズニー行こ
# 16                             稲津です。必要なら中本から連絡ください。
# 18                                              NaN
# 23                                              NaN
# 29                                              NaN
# 36                                              NaN
# 45                                              NaN
# 47                                              NaN
# 49                                              NaN
# 62                                        kaito.a27
# 69                                              NaN
# 74                                         スペの石井だよ。
# 77                                         kakenman
# 85                                              NaN
# 92                                              NaN
# 95                                         上田、自分で回答
# 102                                             NaN
# 107                                             NaN
# 108                                             NaN
# 116                                             NaN
# 123                                             NaN
# 126                                             NaN
# 131                                             NaN
# 140                                             NaN
# 146                                             NaN
# 149                                             NaN
# 154                                             NaN
# 158                                     @user_id_us
# 169                                             NaN
# 170                                      @sub_agent

# %% [markdown]
# # 食べログで保存してる男とインスタの女の比較

# %%
tabelog_man = man_save.copy().dropna(subset=['飲食店の情報はどこに保存していますか？(複数選択可能)'])[np.array([sources.find('食べログ') for sources in man_save.copy().dropna(subset=['飲食店の情報はどこに保存していますか？(複数選択可能)']).iloc[:,8]]) > -1]

# %%
insta_woman = woman_save.copy().dropna(subset=['飲食店の情報はどこに保存していますか？(複数選択可能)'])[np.array([sources.find('Instagram') for sources in woman_save.copy().dropna(subset=['飲食店の情報はどこに保存していますか？(複数選択可能)']).iloc[:,8]]) > -1]

# %%
uniq_often = ['週1~2日', '2週間に1回', '月に1回程度', '実際にそこからお店に行くことはほとんどない']

# %%
tabelog_man_often = tabelog_man.iloc[:,9]
tabelog_man_often_data = np.zeros(len(uniq_often))
for (i, s) in enumerate(uniq_often):
    for p in tabelog_man_often:
        if p == s:
            tabelog_man_often_data[i] += 1
pie_chart(tabelog_man_often_data, uniq_often)

# %%
insta_woman_often = insta_woman.iloc[:,9]
insta_woman_often_data = np.zeros(len(uniq_often))
for (i, s) in enumerate(uniq_often):
    for p in insta_woman_often:
        if p == s:
            insta_woman_often_data[i] += 1
pie_chart(insta_woman_often_data, uniq_often)

# %% [markdown]
# # 考察

# %% [markdown]
# やっぱり思った通り、リア充女子大生が一番コレクションしてる&食べログじゃなくてスクショに頼ってる&いろんなソースがあるなどなどで数字をみたときの需要はありそう。
#
# やっぱりでも便利とかわかりやすい指標はなくて複雑な心理を抱えてる感はあって闇は深い。
#
# 困ってるとおもってない説（森田のように）があるので、その辺は注意が必要そうである。
#
# 女はやっぱり思った通りインスタやスクショでの保存が多い。
#
# 男はいろんなツールを使いこなしている感じ。
#
# 男はメモを使ってたりして、結構ちゃんと保存しておきたい層もいる感じがする。
#
# 意外とニーズは男なのかな。
#
# 男なら便利押しが強い感じがある。
#
# 女なら、楽、おしゃれが大事そう。
#
# ニーズがよりわかりやすいのは男な気もしている。
#
# ただ、数字は出ないかも
