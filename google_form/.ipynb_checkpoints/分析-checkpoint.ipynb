# %% [markdown]
# # import

# %%
import csv

# %%
import matplotlib
import matplotlib as mpl
font = {"family":"AppleGothic"}
mpl.rc('font', **font)
# Out:
# /Users/uedatomohiro/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc

# %%
import matplotlib.pyplot as plt
% matplotlib inline

# %%
import numpy as np

# %%
csv_file = open("./グルメアプリ開発に活かすべくアンケートの協力をお願いしております。.csv", "r", encoding="ms932", errors="", newline="" )

# %%
f = csv.reader(csv_file, delimiter=",", doublequote=True, lineterminator="\r\n", quotechar='"', skipinitialspace=True)

# %%
import pandas as pd

# %%
df = pd.read_csv("./グルメアプリ開発に活かすべくアンケートの協力をお願いしております。.csv")

# %%
df.shape
# Out:
# (177, 11)

# %%
def pie_chart(data, label):
    plt.style.use('ggplot')
    plt.rcParams.update({'font.size':15})

    ###各種パラメータ###
    size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
    col=cm.Spectral(np.arange(len(data))/float(len(data))) #color指定はcolormapから好みのものを。

    ###pie###
    plt.figure(figsize=size,dpi=100)
    plt.pie(data, counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
    plt.subplots_adjust(left=0,right=0.7)
    plt.legend(label,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
    plt.axis('equal') 
    plt.savefig('figure.png',bbox_inches='tight',pad_inches=0.05)

# %% [markdown]
# # 男

# %% [markdown]
# ## 保存する割合

# %%
man_df = df[df.iloc[:,1]=='男']

# %%
man_yes_num = len(man_df[man_df.iloc[:,2]=='はい'])
man_no_num = len(man_df[man_df.iloc[:,2]=='いいえ'])
man_yes_num/(man_no_num+man_yes_num)
plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})
plt.axis('equal')
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
plt.pie([man_yes_num, man_no_num], labels=['yes','no'])
plt.show()

# %%
man_yes_num / (man_yes_num + man_no_num)
# Out:
# 0.371900826446281

# %% [markdown]
# 保存してる人が37%

# %% [markdown]
# ## どこから保存するか

# %%
man_save = man_df[man_df.iloc[:,2]=='はい']
sources = [source.split(';') for source in man_save.iloc[:,7]]
from itertools import chain
sources = list(chain.from_iterable(sources))

sources_uniq = set(sources)

source_data = np.zeros(len(sources))
for (i, s) in enumerate(sources_uniq):
    for source in sources:
        if source == s:
            source_data[i] += 1

data = source_data
label = sources_uniq

import matplotlib.cm as cm

plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})

###各種パラメータ###
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
col=cm.Spectral(np.arange(len(data))/float(len(data))) #color指定はcolormapから好みのものを。

###pie###
plt.figure(figsize=size,dpi=100)
plt.pie(data, counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
plt.subplots_adjust(left=0,right=0.7)
plt.legend(label,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
plt.axis('equal') 
plt.savefig('figure.png',bbox_inches='tight',pad_inches=0.05)

# %% [markdown]
# 食べログが27%
# ニュースアプリが14%
# instaが11.7%
# twitterが11.7%
# これで6割
#
# ニュースアプリ何なのか気になる（聞いてみる？）
#
# 口コミは14％でインスタより多い
#
# HotPepper,　ぐるなびのシェアは実装してもいいかも

# %% [markdown]
# ## 保存した店に行く頻度

# %%
oftens = [source.split(';') for source in man_save.iloc[:,9]]
often = list(chain.from_iterable(oftens))

often_uniq = set(often)

often_data = np.zeros(len(often))
for (i, s) in enumerate(often_uniq):
    for p in often:
        if p == s:
            often_data[i] += 1

data = often_data
label = often_uniq

import matplotlib.cm as cm

plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})

###各種パラメータ###
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
col=cm.Spectral(np.arange(len(data))/float(len(data))) #color指定はcolormapから好みのものを。

###pie###
plt.figure(figsize=size,dpi=100)
plt.pie(data, counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
plt.subplots_adjust(left=0,right=0.7)
plt.legend(label,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
plt.axis('equal') 
plt.savefig('figure.png',bbox_inches='tight',pad_inches=0.05)

# %% [markdown]
# 実際には行かない人が4割

# %% [markdown]
# ## どこに保存するか

# %%
pool = [source.split(';') for source in man_save.iloc[:,8]]
pool = list(chain.from_iterable(pool))

pool_uniq = set(pool)

pool_data = np.zeros(len(pool))
for (i, s) in enumerate(pool_uniq):
    for p in pool:
        if p == s:
            pool_data[i] += 1

data = pool_data
label = pool_uniq

import matplotlib.cm as cm

plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})

###各種パラメータ###
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
col=cm.Spectral(np.arange(len(data))/float(len(data))) #color指定はcolormapから好みのものを。

###pie###
plt.figure(figsize=size,dpi=100)
plt.pie(data, counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
plt.subplots_adjust(left=0,right=0.7)
plt.legend(label,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
plt.axis('equal') 
plt.savefig('figure.png',bbox_inches='tight',pad_inches=0.05)

# %% [markdown]
# スクショが3割
#
# 食べログが2割
#
# これで5割
#
# 食べログ勢の熱量多少ある層が2割
#
# instaのコレクションはほとんどいない
#
# メモが13%でtwitterも1割いる

# %% [markdown]
# # 女

# %% [markdown]
# ## 保存する割合

# %%
woman_yes_num
# Out:
# 38

# %%
woman_no_num
# Out:
# 18

# %%
plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})
plt.axis('equal')
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
plt.pie([woman_yes_num, woman_no_num], labels=['yes','no'])
plt.show()

# %%
32 / 56
# Out:
# 0.5714285714285714

# %% [markdown]
# 保存する人が38人、しない人が18人
#
# する率が57%

# %% [markdown]
# ## どこから保存するか

# %%
woman_save = woman_df[woman_df.iloc[:,2]=='はい']
sources = [source.split(';') for source in woman_save.iloc[:,7]]

# %%
from itertools import chain
sources = list(chain.from_iterable(sources))

sources_uniq = set(sources)

source_data = np.zeros(len(sources))
for (i, s) in enumerate(sources_uniq):
    for source in sources:
        if source == s:
            source_data[i] += 1

data = source_data
label = sources_uniq

import matplotlib.cm as cm

plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})

###各種パラメータ###
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
col=cm.Spectral(np.arange(len(data))/float(len(data))) #color指定はcolormapから好みのものを。

###pie###
plt.figure(figsize=size,dpi=100)
plt.pie(data, counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
plt.subplots_adjust(left=0,right=0.7)
plt.legend(label,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
plt.axis('equal') 
plt.savefig('figure.png',bbox_inches='tight',pad_inches=0.05)

# %% [markdown]
# 男と全然違う
#
# 食べログが21％
#
# インスタが18％
#
# twitterが14％
#
# 口コミはやっぱりあんまりないみたい(insta⊃口コミって感じなのかな)
#
# ぐるなびとhotpepperは意外と1割強ずついる

# %% [markdown]
# ## 保存した店にどれくらい行くか

# %%
oftens = [source.split(';') for source in woman_save.iloc[:,9]]

# %%
often = list(chain.from_iterable(oftens))

often_uniq = set(often)

often_data = np.zeros(len(often))
for (i, s) in enumerate(often_uniq):
    for p in often:
        if p == s:
            often_data[i] += 1

data = often_data
label = often_uniq

import matplotlib.cm as cm

plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})

###各種パラメータ###
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
col=cm.Spectral(np.arange(len(data))/float(len(data))) #color指定はcolormapから好みのものを。

###pie###
plt.figure(figsize=size,dpi=100)
plt.pie(data, counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
plt.subplots_adjust(left=0,right=0.7)
plt.legend(label,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
plt.axis('equal') 
plt.savefig('figure.png',bbox_inches='tight',pad_inches=0.05)

# %% [markdown]
# 月1行く人が多いけどここは男とあんまり変わらないと行ってもいいのかな

# %% [markdown]
# ## どこに保存するか

# %%
pool = [source.split(';') for source in woman_save.iloc[:,8]]

# %%
pool = list(chain.from_iterable(pool))

pool_uniq = set(pool)

pool_data = np.zeros(len(pool))
for (i, s) in enumerate(pool_uniq):
    for p in pool:
        if p == s:
            pool_data[i] += 1

data = pool_data
label = pool_uniq

import matplotlib.cm as cm

plt.style.use('ggplot')
plt.rcParams.update({'font.size':15})

###各種パラメータ###
size=(9,5) #凡例を配置する関係でsizeは横長にしておきます。
col=cm.Spectral(np.arange(len(data))/float(len(data))) #color指定はcolormapから好みのものを。

###pie###
plt.figure(figsize=size,dpi=100)
plt.pie(data, counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
plt.subplots_adjust(left=0,right=0.7)
plt.legend(label,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
plt.axis('equal') 
plt.savefig('figure.png',bbox_inches='tight',pad_inches=0.05)

# %% [markdown]
# スクショがめちゃおおい。
#
# 男にはほぼなかったインスタのコレクションも意外と多い
#
# 食べログ使ってる人はほぼほぼいない←！！！！！
#
# やっぱりあんまりちゃんと管理してる人いない
#
# が、これが管理したいと思ってないのか、やりたいけどできてないのかはわからん

# %% [markdown]
# # 保存してる人としてない人の違い

# %%
woman_df.head()
# Out:
#                          タイムスタンプ 性別を教えてください。  \
# 3   2018/10/18 10:54:56 午後 GMT+9           女
# 5   2018/10/18 10:55:12 午後 GMT+9           女
# 28  2018/10/18 11:05:04 午後 GMT+9           女
# 30  2018/10/18 11:05:15 午後 GMT+9           女
# 31  2018/10/18 11:05:17 午後 GMT+9           女
#
#    お気に入りの飲食店や行きたい飲食店の情報を何らかの方法でスマートフォン内に保存していますか？ 夜に外食する頻度を教えてください。  \
# 3                                              はい         それよりもすくない
# 5                                              はい             週1-2回
# 28                                             はい             週1-2回
# 30                                             はい            2週間に1回
# 31                                             はい             週1-2回
#
#    飲み会に行く頻度を教えてください。 バイトやインターンを教えてください(複数回答可能) 現在交際中の人はいますか？(任意回答)  \
# 3    ほとんど行かない / 行かない                  塾講師・家庭教師                  いる
# 5             2週間に1回       塾講師・家庭教師;営業・マーケティング                 いない
# 28            2週間に1回                    その他飲食店                 いない
# 30   ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 31               月1回                   カフェ;雑貨屋                 NaN
#
#    飲食店の情報はどこから仕入れることが多いですか？(複数選択可能)  \
# 3                      食べログ;Twitter
# 5                     Instagram;口コミ
# 28            Instagram;Twitter;口コミ
# 30           食べログ;Instagram;Twitter
# 31                  Instagram;雑誌;TV
#
#                           飲食店の情報はどこに保存していますか？(複数選択可能)  \
# 3   スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Twit...
# 5                   スクリーンショット;Instagramの「コレクション」や「投稿」
# 28  スクリーンショット;Instagramの「コレクション」や「投稿」;Twitterの「いいね...
# 30             スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」
# 31                  スクリーンショット;Instagramの「コレクション」や「投稿」
#
#    保存している飲食店に行くことはどれくらいありますか？ 気になった方に後日連絡するためにTwitterIDやLINEIDなどを教えてください。(任意)
# 3       実際にそこからお店に行くことはほとんどない                  @kajiguchi97 いつでもどうぞ。頑張ってください！
# 5                      2週間に1回                                             NaN
# 28                     月に1回程度                                             NaN
# 30                     月に1回程度                                             NaN
# 31                     2週間に1回                                        もりたまゆこ💞！

# %%
save_woman = woman_df[woman_df.iloc[:,2]=='はい']
non_save_woman = woman_df[woman_df.iloc[:,2]=='いいえ']

# %%
save_woman.head()
# Out:
#                          タイムスタンプ 性別を教えてください。  \
# 3   2018/10/18 10:54:56 午後 GMT+9           女
# 5   2018/10/18 10:55:12 午後 GMT+9           女
# 28  2018/10/18 11:05:04 午後 GMT+9           女
# 30  2018/10/18 11:05:15 午後 GMT+9           女
# 31  2018/10/18 11:05:17 午後 GMT+9           女
#
#    お気に入りの飲食店や行きたい飲食店の情報を何らかの方法でスマートフォン内に保存していますか？ 夜に外食する頻度を教えてください。  \
# 3                                              はい         それよりもすくない
# 5                                              はい             週1-2回
# 28                                             はい             週1-2回
# 30                                             はい            2週間に1回
# 31                                             はい             週1-2回
#
#    飲み会に行く頻度を教えてください。 バイトやインターンを教えてください(複数回答可能) 現在交際中の人はいますか？(任意回答)  \
# 3    ほとんど行かない / 行かない                  塾講師・家庭教師                  いる
# 5             2週間に1回       塾講師・家庭教師;営業・マーケティング                 いない
# 28            2週間に1回                    その他飲食店                 いない
# 30   ほとんど行かない / 行かない                  塾講師・家庭教師                 いない
# 31               月1回                   カフェ;雑貨屋                 NaN
#
#    飲食店の情報はどこから仕入れることが多いですか？(複数選択可能)  \
# 3                      食べログ;Twitter
# 5                     Instagram;口コミ
# 28            Instagram;Twitter;口コミ
# 30           食べログ;Instagram;Twitter
# 31                  Instagram;雑誌;TV
#
#                           飲食店の情報はどこに保存していますか？(複数選択可能)  \
# 3   スクリーンショット;メモアプリ(「iPhoneのメモ」、「Evernote」など);Twit...
# 5                   スクリーンショット;Instagramの「コレクション」や「投稿」
# 28  スクリーンショット;Instagramの「コレクション」や「投稿」;Twitterの「いいね...
# 30             スクリーンショット;Twitterの「いいね」や「ツイート」や「モーメント」
# 31                  スクリーンショット;Instagramの「コレクション」や「投稿」
#
#    保存している飲食店に行くことはどれくらいありますか？ 気になった方に後日連絡するためにTwitterIDやLINEIDなどを教えてください。(任意)
# 3       実際にそこからお店に行くことはほとんどない                  @kajiguchi97 いつでもどうぞ。頑張ってください！
# 5                      2週間に1回                                             NaN
# 28                     月に1回程度                                             NaN
# 30                     月に1回程度                                             NaN
# 31                     2週間に1回                                        もりたまゆこ💞！

# %%
save_often = save_woman.iloc[:,3]
save_often_uniq = set(save_often)
save_often_data = np.zeros(len(save_often_uniq))
for (i, u) in enumerate(save_often_uniq):
    for s in save_often:
        if s == u:
            save_often_data[i] += 1

# %%
pie_chart(save_often_data, save_often_uniq)

# %%
non_save_often = non_save_woman.iloc[:,3]
non_save_often_uniq = set(non_save_often)
data = np.zeros(len(non_save_often_uniq))
for (i, u) in enumerate(non_save_often_uniq):
    for s in non_save_often:
        if s == u:
            data[i] += 1
